# %%
import pandas as pd
import requests
import re
import time
import os
from bs4 import BeautifulSoup

def task_download_graph_extract(model_name, max_retries=5, delay=5):
    url = f'https://huggingface.co/{model_name}'
    for attempt in range(max_retries):
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            soup = BeautifulSoup(response.content, 'html.parser')
            break
        except (requests.RequestException, requests.Timeout) as e:
            print(f"Attempt {attempt + 1} failed: {e}")
            if attempt < max_retries - 1:
                time.sleep(delay)
            else:
                raise

    task_doc = soup.select_one('body > div > main > div.SVELTE_HYDRATER.contents > header > div > div.mb-3.flex.flex-wrap.md\:mb-4')
    task = (None if task_doc is None else (task_doc.find('a', href=re.compile(r'/models\?pipeline_tag=.*')).text.strip() if task_doc.find('a', href=re.compile(r'/models\?pipeline_tag=.*')) else None))    

    downloads = soup.select_one('body > div:nth-of-type(1) > main > div:nth-of-type(2) > section:nth-of-type(2) > div:nth-of-type(1) > dl > dd')
    total = None if downloads is None else downloads.text.replace(',', '')

    target_div = soup.select_one('html > body > div > main > div:nth-of-type(2) > section:nth-of-type(2) > div:nth-of-type(1) > div')
    d_attribute = (target_div := soup.select_one('html > body > div > main > div:nth-of-type(2) > section:nth-of-type(2) > div:nth-of-type(1) > div')) and (first_path := target_div.find('path')) and first_path.get('d', None) or None

    return task, total, d_attribute

def parse_path_data(path_data):
    coordinates = re.findall(r'[-+]?[0-9]*\.?[0-9]+', path_data)
    points = [(float(coordinates[i]), float(coordinates[i + 1])) for i in range(0, len(coordinates), 2)]
    return points

def cal_graph(path_data, download_total):
    if path_data is None:
        return [0] * 30
    else:
        try:
            points = parse_path_data(path_data)
        except IndexError:
            return [0] * 30

        points = parse_path_data(path_data)
        max_day = max(point[0] for point in points)
        scale_factor = 30 / max_day
        normalized_points = [(x * scale_factor, 100 - y) for x, y in points]
        daily_downloads = [0] * 30

        for i in range(len(normalized_points) - 1):
            start_day, start_value = normalized_points[i]
            end_day, end_value = normalized_points[i + 1]
            start_day_int = int(start_day)
            end_day_int = int(end_day)
            range_span = end_day - start_day

            if start_day_int == end_day_int:
                if start_day_int < 30:
                    daily_downloads[start_day_int] += (start_value + end_value) / 2
            else:
                increment = (end_value - start_value) / range_span
                for j in range(start_day_int, min(end_day_int + 1, 30)):
                    if j == start_day_int:
                        fraction = 1 - (start_day - start_day_int)
                        daily_downloads[j] += start_value + fraction * increment
                    elif j == end_day_int:
                        fraction = end_day - end_day_int
                        daily_downloads[j] += start_value + fraction * increment
                    else:
                        fraction = (j - start_day) / (end_day - start_day)
                        daily_downloads[j] += start_value + fraction * increment

        total_downloads = sum(daily_downloads)
        scaling_factor = float(download_total) / total_downloads
        daily_downloads = [d * scaling_factor for d in daily_downloads]
        daily_downloads = [int(round(d)) for d in daily_downloads]

        difference = int(download_total) - sum(daily_downloads)
        adjustment_indices = list(range(30)) if difference > 0 else list(range(29, -1, -1))

        for i in range(abs(difference)):
            daily_downloads[adjustment_indices[i % 30]] += 1 if difference > 0 else -1

        for i in range(30):
            if daily_downloads[i] < 0:
                surplus = -daily_downloads[i]
                daily_downloads[i] = 0
                for j in range(30):
                    if daily_downloads[j] > surplus:
                        daily_downloads[j] -= surplus
                        break
                    else:
                        surplus -= daily_downloads[j]
                        daily_downloads[j] = 0

        return daily_downloads

def save_excel(model_name, start_index, end_index):
    model_task, download_total, path_data = task_download_graph_extract(model_name)
    daily_downloads = cal_graph(path_data, download_total)
    if model_task and model_task.lower() == 'transformers':
        model_task = None
    data = {
        "Model_name": [model_name],
        "Model_task": [model_task],
        **{f"{i+1}Day": [daily_downloads[i]] for i in range(30)},
    }
    df = pd.DataFrame(data)
    output_file = f"20240615_Daily_Download.csv"
    if os.path.exists(output_file):
        existing_df = pd.read_csv(output_file)
        combined_df = pd.concat([existing_df, df], ignore_index=True)
    else:
        combined_df = df
    
    combined_df.to_csv(output_file, index=False)

# Read the input CSV file
file_path = r"./sorted_hugging_face_model_influence_with_scores.csv"
df = pd.read_csv(file_path)
# 데이터프레임을 영향력 점수를 기준으로 내림차순으로 정렬
result_df = df.sort_values(by='total_score', ascending=False)
model_list = result_df['id'].tolist()
print(f"총 행 수: {len(model_list)} 행")

for i in range(0, 10000):
    print(model_list[i])
    save_excel(model_list[i], 0, len(model_list))
    print(f"{i+1}번 모델 데이터 수집 중입니다.")

print("Data collection completed")
# Out:
# <>:23: SyntaxWarning: invalid escape sequence '\:'
# <>:23: SyntaxWarning: invalid escape sequence '\:'
# C:\Users\koyuk\AppData\Local\Temp\ipykernel_6780\123300222.py:23: SyntaxWarning: invalid escape sequence '\:'
#   task_doc = soup.select_one('body > div > main > div.SVELTE_HYDRATER.contents > header > div > div.mb-3.flex.flex-wrap.md\:mb-4')
# 총 행 수: 717070 행
# google-bert/bert-base-uncased
# 1번 모델 데이터 수집 중입니다.
# openai/clip-vit-large-patch14
# 2번 모델 데이터 수집 중입니다.
# openai-community/gpt2
# 3번 모델 데이터 수집 중입니다.
# MIT/ast-finetuned-audioset-10-10-0.4593
# 4번 모델 데이터 수집 중입니다.
# distilbert/distilbert-base-uncased
# 5번 모델 데이터 수집 중입니다.
# sentence-transformers/all-MiniLM-L6-v2
# 6번 모델 데이터 수집 중입니다.
# openai/clip-vit-base-patch32
# 7번 모델 데이터 수집 중입니다.
# facebook/bart-large-cnn
# 8번 모델 데이터 수집 중입니다.
# FacebookAI/xlm-roberta-base
# 9번 모델 데이터 수집 중입니다.
# FacebookAI/roberta-base
# 10번 모델 데이터 수집 중입니다.
# google-bert/bert-base-chinese
# 11번 모델 데이터 수집 중입니다.
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# 12번 모델 데이터 수집 중입니다.
# openai/whisper-large-v3
# 13번 모델 데이터 수집 중입니다.
# google-t5/t5-base
# 14번 모델 데이터 수집 중입니다.
# google-bert/bert-base-multilingual-cased
# 15번 모델 데이터 수집 중입니다.
# facebook/bart-large-mnli
# 16번 모델 데이터 수집 중입니다.
# google/vit-base-patch16-224
# 17번 모델 데이터 수집 중입니다.
# runwayml/stable-diffusion-v1-5
# 18번 모델 데이터 수집 중입니다.
# FacebookAI/roberta-large
# 19번 모델 데이터 수집 중입니다.
# google/vit-base-patch16-224-in21k
# 20번 모델 데이터 수집 중입니다.
# distilbert/distilgpt2
# 21번 모델 데이터 수집 중입니다.
# FacebookAI/xlm-roberta-large
# 22번 모델 데이터 수집 중입니다.
# microsoft/trocr-base-handwritten
# 23번 모델 데이터 수집 중입니다.
# google-bert/bert-base-cased
# 24번 모델 데이터 수집 중입니다.
# mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis
# 25번 모델 데이터 수집 중입니다.
# sentence-transformers/all-mpnet-base-v2
# 26번 모델 데이터 수집 중입니다.
# deepset/roberta-base-squad2
# 27번 모델 데이터 수집 중입니다.
# dslim/bert-base-NER
# 28번 모델 데이터 수집 중입니다.
# google-t5/t5-small
# 29번 모델 데이터 수집 중입니다.
# microsoft/layoutlmv3-base
# 30번 모델 데이터 수집 중입니다.
# stabilityai/stable-diffusion-xl-base-1.0
# 31번 모델 데이터 수집 중입니다.
# microsoft/phi-2
# 32번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-zh-en
# 33번 모델 데이터 수집 중입니다.
# facebook/detr-resnet-50
# 34번 모델 데이터 수집 중입니다.
# EleutherAI/gpt-j-6b
# 35번 모델 데이터 수집 중입니다.
# CompVis/stable-diffusion-v1-4
# 36번 모델 데이터 수집 중입니다.
# google/flan-t5-large
# 37번 모델 데이터 수집 중입니다.
# papluca/xlm-roberta-base-language-detection
# 38번 모델 데이터 수집 중입니다.
# Salesforce/blip-image-captioning-large
# 39번 모델 데이터 수집 중입니다.
# openai/whisper-large-v2
# 40번 모델 데이터 수집 중입니다.
# google/flan-t5-base
# 41번 모델 데이터 수집 중입니다.
# facebook/nllb-200-distilled-600M
# 42번 모델 데이터 수집 중입니다.
# jonatasgrosman/wav2vec2-large-xlsr-53-english
# 43번 모델 데이터 수집 중입니다.
# distilbert/distilroberta-base
# 44번 모델 데이터 수집 중입니다.
# facebook/m2m100_418M
# 45번 모델 데이터 수집 중입니다.
# microsoft/resnet-50
# 46번 모델 데이터 수집 중입니다.
# MoritzLaurer/DeBERTa-v3-base-mnli-fever-anli
# 47번 모델 데이터 수집 중입니다.
# Qwen/Qwen-VL-Chat
# 48번 모델 데이터 수집 중입니다.
# SamLowe/roberta-base-go_emotions
# 49번 모델 데이터 수집 중입니다.
# facebook/opt-125m
# 50번 모델 데이터 수집 중입니다.
# openai/whisper-small
# 51번 모델 데이터 수집 중입니다.
# tiiuae/falcon-7b-instruct
# 52번 모델 데이터 수집 중입니다.
# THUDM/chatglm2-6b
# 53번 모델 데이터 수집 중입니다.
# colbert-ir/colbertv2.0
# 54번 모델 데이터 수집 중입니다.
# openai/whisper-base
# 55번 모델 데이터 수집 중입니다.
# albert/albert-base-v2
# 56번 모델 데이터 수집 중입니다.
# almanach/camembert-base
# 57번 모델 데이터 수집 중입니다.
# cardiffnlp/twitter-roberta-base-sentiment-latest
# 58번 모델 데이터 수집 중입니다.
# google/flan-t5-xxl
# 59번 모델 데이터 수집 중입니다.
# distilbert/distilbert-base-multilingual-cased
# 60번 모델 데이터 수집 중입니다.
# nlptown/bert-base-multilingual-uncased-sentiment
# 61번 모델 데이터 수집 중입니다.
# google/electra-base-discriminator
# 62번 모델 데이터 수집 중입니다.
# google-bert/bert-large-uncased
# 63번 모델 데이터 수집 중입니다.
# openai-community/gpt2-large
# 64번 모델 데이터 수집 중입니다.
# openai-community/gpt2-xl
# 65번 모델 데이터 수집 중입니다.
# microsoft/Phi-3-mini-4k-instruct
# 66번 모델 데이터 수집 중입니다.
# sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# 67번 모델 데이터 수집 중입니다.
# TinyLlama/TinyLlama-1.1B-Chat-v1.0
# 68번 모델 데이터 수집 중입니다.
# dslim/bert-large-NER
# 69번 모델 데이터 수집 중입니다.
# briaai/RMBG-1.4
# 70번 모델 데이터 수집 중입니다.
# distilbert/distilbert-base-cased-distilled-squad
# 71번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-en-zh
# 72번 모델 데이터 수집 중입니다.
# google-bert/bert-base-multilingual-uncased
# 73번 모델 데이터 수집 중입니다.
# sentence-transformers/all-MiniLM-L12-v2
# 74번 모델 데이터 수집 중입니다.
# MoritzLaurer/mDeBERTa-v3-base-xnli-multilingual-nli-2mil7
# 75번 모델 데이터 수집 중입니다.
# Salesforce/blip-image-captioning-base
# 76번 모델 데이터 수집 중입니다.
# openai-community/gpt2-medium
# 77번 모델 데이터 수집 중입니다.
# oliverguhr/fullstop-punctuation-multilang-large
# 78번 모델 데이터 수집 중입니다.
# stabilityai/stable-diffusion-2-1
# 79번 모델 데이터 수집 중입니다.
# nlpconnect/vit-gpt2-image-captioning
# 80번 모델 데이터 수집 중입니다.
# microsoft/Phi-3-mini-128k-instruct
# 81번 모델 데이터 수집 중입니다.
# tiiuae/falcon-40b-instruct
# 82번 모델 데이터 수집 중입니다.
# HuggingFaceH4/zephyr-7b-beta
# 83번 모델 데이터 수집 중입니다.
# ai-forever/sbert_large_nlu_ru
# 84번 모델 데이터 수집 중입니다.
# bigscience/bloom-7b1
# 85번 모델 데이터 수집 중입니다.
# stabilityai/sdxl-turbo
# 86번 모델 데이터 수집 중입니다.
# microsoft/phi-1_5
# 87번 모델 데이터 수집 중입니다.
# lxyuan/distilbert-base-multilingual-cased-sentiments-student
# 88번 모델 데이터 수집 중입니다.
# THUDM/chatglm3-6b
# 89번 모델 데이터 수집 중입니다.
# hustvl/yolos-tiny
# 90번 모델 데이터 수집 중입니다.
# microsoft/DialoGPT-medium
# 91번 모델 데이터 수집 중입니다.
# kresnik/wav2vec2-large-xlsr-korean
# 92번 모델 데이터 수집 중입니다.
# microsoft/DialoGPT-large
# 93번 모델 데이터 수집 중입니다.
# facebook/detr-resnet-101
# 94번 모델 데이터 수집 중입니다.
# cardiffnlp/twitter-xlm-roberta-base-sentiment
# 95번 모델 데이터 수집 중입니다.
# mattmdjaga/segformer_b2_clothes
# 96번 모델 데이터 수집 중입니다.
# laion/CLIP-ViT-B-32-laion2B-s34B-b79K
# 97번 모델 데이터 수집 중입니다.
# google/flan-t5-xl
# 98번 모델 데이터 수집 중입니다.
# runwayml/stable-diffusion-inpainting
# 99번 모델 데이터 수집 중입니다.
# microsoft/layoutlm-base-uncased
# 100번 모델 데이터 수집 중입니다.
# llava-hf/llava-v1.6-mistral-7b-hf
# 101번 모델 데이터 수집 중입니다.
# bigscience/bloom
# 102번 모델 데이터 수집 중입니다.
# bigscience/bloom-560m
# 103번 모델 데이터 수집 중입니다.
# Intel/dpt-large
# 104번 모델 데이터 수집 중입니다.
# Falconsai/nsfw_image_detection
# 105번 모델 데이터 수집 중입니다.
# BAAI/bge-reranker-large
# 106번 모델 데이터 수집 중입니다.
# liuhaotian/llava-v1.5-7b
# 107번 모델 데이터 수집 중입니다.
# facebook/mbart-large-50-many-to-many-mmt
# 108번 모델 데이터 수집 중입니다.
# google/canine-c
# 109번 모델 데이터 수집 중입니다.
# EleutherAI/gpt-neo-125m
# 110번 모델 데이터 수집 중입니다.
# mosaicml/mpt-7b
# 111번 모델 데이터 수집 중입니다.
# microsoft/speecht5_tts
# 112번 모델 데이터 수집 중입니다.
# microsoft/table-transformer-detection
# 113번 모델 데이터 수집 중입니다.
# ProsusAI/finbert
# 114번 모델 데이터 수집 중입니다.
# openai/clip-vit-large-patch14-336
# 115번 모델 데이터 수집 중입니다.
# EleutherAI/gpt-neo-1.3B
# 116번 모델 데이터 수집 중입니다.
# lmsys/fastchat-t5-3b-v1.0
# 117번 모델 데이터 수집 중입니다.
# MoritzLaurer/mDeBERTa-v3-base-mnli-xnli
# 118번 모델 데이터 수집 중입니다.
# google/fnet-base
# 119번 모델 데이터 수집 중입니다.
# medicalai/ClinicalBERT
# 120번 모델 데이터 수집 중입니다.
# EleutherAI/gpt-neo-2.7B
# 121번 모델 데이터 수집 중입니다.
# openai/whisper-tiny
# 122번 모델 데이터 수집 중입니다.
# microsoft/trocr-large-printed
# 123번 모델 데이터 수집 중입니다.
# facebook/wav2vec2-base-960h
# 124번 모델 데이터 수집 중입니다.
# lmsys/vicuna-7b-v1.5
# 125번 모델 데이터 수집 중입니다.
# tohoku-nlp/bert-base-japanese
# 126번 모델 데이터 수집 중입니다.
# Ashishkr/query_wellformedness_score
# 127번 모델 데이터 수집 중입니다.
# google/flan-ul2
# 128번 모델 데이터 수집 중입니다.
# microsoft/trocr-base-printed
# 129번 모델 데이터 수집 중입니다.
# CompVis/stable-diffusion-safety-checker
# 130번 모델 데이터 수집 중입니다.
# Rostlab/prot_bert
# 131번 모델 데이터 수집 중입니다.
# facebook/opt-1.3b
# 132번 모델 데이터 수집 중입니다.
# openai/clip-vit-base-patch16
# 133번 모델 데이터 수집 중입니다.
# nomic-ai/nomic-embed-text-v1.5
# 134번 모델 데이터 수집 중입니다.
# google/flan-t5-small
# 135번 모델 데이터 수집 중입니다.
# Salesforce/blip2-opt-2.7b
# 136번 모델 데이터 수집 중입니다.
# tiiuae/falcon-7b
# 137번 모델 데이터 수집 중입니다.
# allenai/longformer-base-4096
# 138번 모델 데이터 수집 중입니다.
# microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext
# 139번 모델 데이터 수집 중입니다.
# openai/whisper-medium
# 140번 모델 데이터 수집 중입니다.
# microsoft/Phi-3-vision-128k-instruct
# 141번 모델 데이터 수집 중입니다.
# google-bert/bert-large-uncased-whole-word-masking-finetuned-squad
# 142번 모델 데이터 수집 중입니다.
# FacebookAI/roberta-large-mnli
# 143번 모델 데이터 수집 중입니다.
# madhurjindal/autonlp-Gibberish-Detector-492513457
# 144번 모델 데이터 수집 중입니다.
# liuhaotian/llava-v1.5-13b
# 145번 모델 데이터 수집 중입니다.
# tiiuae/falcon-40b
# 146번 모델 데이터 수집 중입니다.
# stabilityai/stable-diffusion-xl-refiner-1.0
# 147번 모델 데이터 수집 중입니다.
# google-bert/bert-base-german-cased
# 148번 모델 데이터 수집 중입니다.
# facebook/opt-350m
# 149번 모델 데이터 수집 중입니다.
# teknium/OpenHermes-2.5-Mistral-7B
# 150번 모델 데이터 수집 중입니다.
# Gustavosta/MagicPrompt-Stable-Diffusion
# 151번 모델 데이터 수집 중입니다.
# tohoku-nlp/bert-base-japanese-whole-word-masking
# 152번 모델 데이터 수집 중입니다.
# siebert/sentiment-roberta-large-english
# 153번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-es-en
# 154번 모델 데이터 수집 중입니다.
# facebook/seamless-m4t-v2-large
# 155번 모델 데이터 수집 중입니다.
# microsoft/table-transformer-structure-recognition
# 156번 모델 데이터 수집 중입니다.
# openai-community/roberta-base-openai-detector
# 157번 모델 데이터 수집 중입니다.
# laion/CLIP-ViT-H-14-laion2B-s32B-b79K
# 158번 모델 데이터 수집 중입니다.
# openai-community/openai-gpt
# 159번 모델 데이터 수집 중입니다.
# EleutherAI/gpt-neox-20b
# 160번 모델 데이터 수집 중입니다.
# THUDM/chatglm-6b
# 161번 모델 데이터 수집 중입니다.
# facebook/dinov2-base
# 162번 모델 데이터 수집 중입니다.
# humarin/chatgpt_paraphraser_on_T5_base
# 163번 모델 데이터 수집 중입니다.
# facebook/m2m100_1.2B
# 164번 모델 데이터 수집 중입니다.
# ElKulako/cryptobert
# 165번 모델 데이터 수집 중입니다.
# sentence-transformers/distiluse-base-multilingual-cased-v2
# 166번 모델 데이터 수집 중입니다.
# openbmb/MiniCPM-Llama3-V-2_5
# 167번 모델 데이터 수집 중입니다.
# TahaDouaji/detr-doc-table-detection
# 168번 모델 데이터 수집 중입니다.
# microsoft/deberta-v3-base
# 169번 모델 데이터 수집 중입니다.
# HuggingFaceH4/zephyr-7b-alpha
# 170번 모델 데이터 수집 중입니다.
# shibing624/text2vec-base-chinese
# 171번 모델 데이터 수집 중입니다.
# distilbert/distilbert-base-cased
# 172번 모델 데이터 수집 중입니다.
# finiteautomata/bertweet-base-sentiment-analysis
# 173번 모델 데이터 수집 중입니다.
# stabilityai/stable-diffusion-2
# 174번 모델 데이터 수집 중입니다.
# mistralai/Mistral-7B-Instruct-v0.2
# 175번 모델 데이터 수집 중입니다.
# NousResearch/Llama-2-7b-chat-hf
# 176번 모델 데이터 수집 중입니다.
# h94/IP-Adapter-FaceID
# 177번 모델 데이터 수집 중입니다.
# sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# 178번 모델 데이터 수집 중입니다.
# nateraw/vit-age-classifier
# 179번 모델 데이터 수집 중입니다.
# ai21labs/Jamba-v0.1
# 180번 모델 데이터 수집 중입니다.
# j-hartmann/emotion-english-distilroberta-base
# 181번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-ru-en
# 182번 모델 데이터 수집 중입니다.
# microsoft/resnet-18
# 183번 모델 데이터 수집 중입니다.
# HuggingFaceM4/idefics2-8b
# 184번 모델 데이터 수집 중입니다.
# cardiffnlp/twitter-roberta-base-sentiment
# 185번 모델 데이터 수집 중입니다.
# jonathandinu/face-parsing
# 186번 모델 데이터 수집 중입니다.
# sentence-transformers/multi-qa-MiniLM-L6-cos-v1
# 187번 모델 데이터 수집 중입니다.
# FacebookAI/xlm-roberta-large-finetuned-conll03-english
# 188번 모델 데이터 수집 중입니다.
# bigscience/T0pp
# 189번 모델 데이터 수집 중입니다.
# suno/bark
# 190번 모델 데이터 수집 중입니다.
# openai/whisper-large
# 191번 모델 데이터 수집 중입니다.
# dbmdz/bert-large-cased-finetuned-conll03-english
# 192번 모델 데이터 수집 중입니다.
# cardiffnlp/twitter-roberta-base-irony
# 193번 모델 데이터 수집 중입니다.
# TinyPixel/Llama-2-7B-bf16-sharded
# 194번 모델 데이터 수집 중입니다.
# ByteDance/SDXL-Lightning
# 195번 모델 데이터 수집 중입니다.
# Lykon/DreamShaper
# 196번 모델 데이터 수집 중입니다.
# ehcalabres/wav2vec2-lg-xlsr-en-speech-emotion-recognition
# 197번 모델 데이터 수집 중입니다.
# vennify/t5-base-grammar-correction
# 198번 모델 데이터 수집 중입니다.
# coqui/XTTS-v2
# 199번 모델 데이터 수집 중입니다.
# distilbert/distilbert-base-uncased-distilled-squad
# 200번 모델 데이터 수집 중입니다.
# facebook/sam-vit-base
# 201번 모델 데이터 수집 중입니다.
# sentence-transformers/paraphrase-MiniLM-L6-v2
# 202번 모델 데이터 수집 중입니다.
# google/electra-small-discriminator
# 203번 모델 데이터 수집 중입니다.
# dccuchile/bert-base-spanish-wwm-uncased
# 204번 모델 데이터 수집 중입니다.
# dangvantuan/sentence-camembert-large
# 205번 모델 데이터 수집 중입니다.
# microsoft/trocr-large-stage1
# 206번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-fr-en
# 207번 모델 데이터 수집 중입니다.
# facebook/vit-mae-base
# 208번 모델 데이터 수집 중입니다.
# mistralai/Mistral-7B-v0.1
# 209번 모델 데이터 수집 중입니다.
# facebook/contriever
# 210번 모델 데이터 수집 중입니다.
# upstage/SOLAR-10.7B-Instruct-v1.0
# 211번 모델 데이터 수집 중입니다.
# google/mt5-small
# 212번 모델 데이터 수집 중입니다.
# openai/whisper-tiny.en
# 213번 모델 데이터 수집 중입니다.
# TheBloke/Mixtral-8x7B-Instruct-v0.1-GGUF
# 214번 모델 데이터 수집 중입니다.
# stabilityai/stable-diffusion-2-1-base
# 215번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-de-en
# 216번 모델 데이터 수집 중입니다.
# TheBloke/Mixtral-8x7B-Instruct-v0.1-GPTQ
# 217번 모델 데이터 수집 중입니다.
# TheBloke/Llama-2-7B-Chat-GGUF
# 218번 모델 데이터 수집 중입니다.
# google/owlvit-base-patch32
# 219번 모델 데이터 수집 중입니다.
# intfloat/multilingual-e5-large
# 220번 모델 데이터 수집 중입니다.
# google/bert_uncased_L-2_H-128_A-2
# 221번 모델 데이터 수집 중입니다.
# microsoft/deberta-base
# 222번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-en-fr
# 223번 모델 데이터 수집 중입니다.
# nvidia/segformer-b0-finetuned-ade-512-512
# 224번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-en-es
# 225번 모델 데이터 수집 중입니다.
# Intel/dpt-hybrid-midas
# 226번 모델 데이터 수집 중입니다.
# uer/roberta-base-finetuned-chinanews-chinese
# 227번 모델 데이터 수집 중입니다.
# CIDAS/clipseg-rd64-refined
# 228번 모델 데이터 수집 중입니다.
# microsoft/trocr-small-handwritten
# 229번 모델 데이터 수집 중입니다.
# facebook/fasttext-language-identification
# 230번 모델 데이터 수집 중입니다.
# Qwen/Qwen-7B-Chat
# 231번 모델 데이터 수집 중입니다.
# TheBloke/Mistral-7B-Instruct-v0.1-GGUF
# 232번 모델 데이터 수집 중입니다.
# chavinlo/alpaca-native
# 233번 모델 데이터 수집 중입니다.
# openchat/openchat_3.5
# 234번 모델 데이터 수집 중입니다.
# codellama/CodeLlama-34b-Instruct-hf
# 235번 모델 데이터 수집 중입니다.
# sentence-transformers/multi-qa-mpnet-base-dot-v1
# 236번 모델 데이터 수집 중입니다.
# mistralai/Mixtral-8x7B-Instruct-v0.1
# 237번 모델 데이터 수집 중입니다.
# distil-whisper/distil-large-v2
# 238번 모델 데이터 수집 중입니다.
# google/siglip-so400m-patch14-384
# 239번 모델 데이터 수집 중입니다.
# MCG-NJU/videomae-base
# 240번 모델 데이터 수집 중입니다.
# databricks/dolly-v2-3b
# 241번 모델 데이터 수집 중입니다.
# pyannote/speaker-diarization
# 242번 모델 데이터 수집 중입니다.
# prithivida/parrot_paraphraser_on_T5
# 243번 모델 데이터 수집 중입니다.
# google-t5/t5-3b
# 244번 모델 데이터 수집 중입니다.
# vikhyatk/moondream1
# 245번 모델 데이터 수집 중입니다.
# sentence-transformers/LaBSE
# 246번 모델 데이터 수집 중입니다.
# Davlan/bert-base-multilingual-cased-ner-hrl
# 247번 모델 데이터 수집 중입니다.
# Alibaba-NLP/gte-large-en-v1.5
# 248번 모델 데이터 수집 중입니다.
# vikhyatk/moondream2
# 249번 모델 데이터 수집 중입니다.
# HuggingFaceFW/fineweb-edu-classifier
# 250번 모델 데이터 수집 중입니다.
# emilyalsentzer/Bio_ClinicalBERT
# 251번 모델 데이터 수집 중입니다.
# 01-ai/Yi-34B
# 252번 모델 데이터 수집 중입니다.
# ibm-granite/granite-timeseries-ttm-v1
# 253번 모델 데이터 수집 중입니다.
# audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim
# 254번 모델 데이터 수집 중입니다.
# facebook/encodec_24khz
# 255번 모델 데이터 수집 중입니다.
# facebook/musicgen-small
# 256번 모델 데이터 수집 중입니다.
# mistralai/Mixtral-8x7B-v0.1
# 257번 모델 데이터 수집 중입니다.
# stabilityai/stable-video-diffusion-img2vid-xt
# 258번 모델 데이터 수집 중입니다.
# zhihan1996/DNA_bert_6
# 259번 모델 데이터 수집 중입니다.
# microsoft/Phi-3-medium-128k-instruct
# 260번 모델 데이터 수집 중입니다.
# pysentimiento/robertuito-sentiment-analysis
# 261번 모델 데이터 수집 중입니다.
# unitary/toxic-bert
# 262번 모델 데이터 수집 중입니다.
# microsoft/xclip-base-patch32
# 263번 모델 데이터 수집 중입니다.
# allenai/scibert_scivocab_uncased
# 264번 모델 데이터 수집 중입니다.
# sshleifer/distilbart-cnn-12-6
# 265번 모델 데이터 수집 중입니다.
# openchat/openchat-3.5-0106
# 266번 모델 데이터 수집 중입니다.
# BAAI/bge-m3
# 267번 모델 데이터 수집 중입니다.
# baichuan-inc/Baichuan-7B
# 268번 모델 데이터 수집 중입니다.
# unsloth/llama-3-8b-bnb-4bit
# 269번 모델 데이터 수집 중입니다.
# kredor/punctuate-all
# 270번 모델 데이터 수집 중입니다.
# codellama/CodeLlama-7b-hf
# 271번 모델 데이터 수집 중입니다.
# d4data/biomedical-ner-all
# 272번 모델 데이터 수집 중입니다.
# google/tapas-large-finetuned-wtq
# 273번 모델 데이터 수집 중입니다.
# TheBloke/Mistral-7B-Instruct-v0.2-GGUF
# 274번 모델 데이터 수집 중입니다.
# Jean-Baptiste/camembert-ner
# 275번 모델 데이터 수집 중입니다.
# jonatasgrosman/wav2vec2-large-xlsr-53-chinese-zh-cn
# 276번 모델 데이터 수집 중입니다.
# BAAI/bge-large-en-v1.5
# 277번 모델 데이터 수집 중입니다.
# BAAI/bge-large-en
# 278번 모델 데이터 수집 중입니다.
# distil-whisper/distil-medium.en
# 279번 모델 데이터 수집 중입니다.
# mixedbread-ai/mxbai-embed-large-v1
# 280번 모델 데이터 수집 중입니다.
# microsoft/DialoGPT-small
# 281번 모델 데이터 수집 중입니다.
# myshell-ai/MeloTTS-English
# 282번 모델 데이터 수집 중입니다.
# BAAI/bge-large-zh-v1.5
# 283번 모델 데이터 수집 중입니다.
# lmsys/vicuna-13b-v1.5
# 284번 모델 데이터 수집 중입니다.
# deepset/bert-large-uncased-whole-word-masking-squad2
# 285번 모델 데이터 수집 중입니다.
# microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract
# 286번 모델 데이터 수집 중입니다.
# NousResearch/Llama-2-7b-hf
# 287번 모델 데이터 수집 중입니다.
# ai-forever/mGPT
# 288번 모델 데이터 수집 중입니다.
# openai-community/roberta-large-openai-detector
# 289번 모델 데이터 수집 중입니다.
# liuhaotian/llava-v1.6-mistral-7b
# 290번 모델 데이터 수집 중입니다.
# berkeley-nest/Starling-LM-7B-alpha
# 291번 모델 데이터 수집 중입니다.
# nlpaueb/legal-bert-base-uncased
# 292번 모델 데이터 수집 중입니다.
# human-centered-summarization/financial-summarization-pegasus
# 293번 모델 데이터 수집 중입니다.
# cointegrated/rubert-tiny
# 294번 모델 데이터 수집 중입니다.
# Phind/Phind-CodeLlama-34B-v2
# 295번 모델 데이터 수집 중입니다.
# pyannote/segmentation
# 296번 모델 데이터 수집 중입니다.
# cointegrated/rubert-base-cased-nli-threeway
# 297번 모델 데이터 수집 중입니다.
# deepset/tinyroberta-squad2
# 298번 모델 데이터 수집 중입니다.
# yangheng/deberta-v3-base-absa-v1.1
# 299번 모델 데이터 수집 중입니다.
# mosaicml/mpt-7b-storywriter
# 300번 모델 데이터 수집 중입니다.
# dbmdz/bert-base-turkish-cased
# 301번 모델 데이터 수집 중입니다.
# facebook/mms-1b-all
# 302번 모델 데이터 수집 중입니다.
# hustvl/yolos-small
# 303번 모델 데이터 수집 중입니다.
# nvidia/Llama3-ChatQA-1.5-8B
# 304번 모델 데이터 수집 중입니다.
# BAAI/bge-small-en-v1.5
# 305번 모델 데이터 수집 중입니다.
# Salesforce/blip-vqa-base
# 306번 모델 데이터 수집 중입니다.
# Salesforce/instructblip-vicuna-7b
# 307번 모델 데이터 수집 중입니다.
# microsoft/beit-base-patch16-224-pt22k-ft22k
# 308번 모델 데이터 수집 중입니다.
# sentence-transformers/bert-base-nli-mean-tokens
# 309번 모델 데이터 수집 중입니다.
# prajjwal1/bert-tiny
# 310번 모델 데이터 수집 중입니다.
# codellama/CodeLlama-7b-Instruct-hf
# 311번 모델 데이터 수집 중입니다.
# Open-Orca/Mistral-7B-OpenOrca
# 312번 모델 데이터 수집 중입니다.
# databricks/dolly-v2-12b
# 313번 모델 데이터 수집 중입니다.
# 01-ai/Yi-34B-Chat
# 314번 모델 데이터 수집 중입니다.
# BAAI/bge-small-en
# 315번 모델 데이터 수집 중입니다.
# distil-whisper/distil-large-v3
# 316번 모델 데이터 수집 중입니다.
# cognitivecomputations/dolphin-2.5-mixtral-8x7b
# 317번 모델 데이터 수집 중입니다.
# togethercomputer/LLaMA-2-7B-32K
# 318번 모델 데이터 수집 중입니다.
# gradientai/Llama-3-8B-Instruct-Gradient-1048k
# 319번 모델 데이터 수집 중입니다.
# facebook/sam-vit-huge
# 320번 모델 데이터 수집 중입니다.
# Babelscape/rebel-large
# 321번 모델 데이터 수집 중입니다.
# jonatasgrosman/wav2vec2-large-xlsr-53-russian
# 322번 모델 데이터 수집 중입니다.
# google-t5/t5-large
# 323번 모델 데이터 수집 중입니다.
# facebook/rag-token-nq
# 324번 모델 데이터 수집 중입니다.
# liuhaotian/llava-v1.6-vicuna-7b
# 325번 모델 데이터 수집 중입니다.
# naver-clova-ix/donut-base-finetuned-docvqa
# 326번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-mul-en
# 327번 모델 데이터 수집 중입니다.
# stabilityai/stable-code-3b
# 328번 모델 데이터 수집 중입니다.
# llava-hf/llava-1.5-7b-hf
# 329번 모델 데이터 수집 중입니다.
# philschmid/bart-large-cnn-samsum
# 330번 모델 데이터 수집 중입니다.
# timbrooks/instruct-pix2pix
# 331번 모델 데이터 수집 중입니다.
# yiyanghkust/finbert-tone
# 332번 모델 데이터 수집 중입니다.
# facebook/bart-base
# 333번 모델 데이터 수집 중입니다.
# microsoft/codebert-base
# 334번 모델 데이터 수집 중입니다.
# facebook/wav2vec2-large-xlsr-53
# 335번 모델 데이터 수집 중입니다.
# mosaicml/mpt-30b
# 336번 모델 데이터 수집 중입니다.
# microsoft/trocr-large-handwritten
# 337번 모델 데이터 수집 중입니다.
# hatmimoha/arabic-ner
# 338번 모델 데이터 수집 중입니다.
# mistralai/Mistral-7B-Instruct-v0.1
# 339번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-ar-en
# 340번 모델 데이터 수집 중입니다.
# NousResearch/Hermes-2-Pro-Llama-3-8B
# 341번 모델 데이터 수집 중입니다.
# mosaicml/mpt-7b-chat
# 342번 모델 데이터 수집 중입니다.
# amazon/chronos-t5-large
# 343번 모델 데이터 수집 중입니다.
# facebook/detr-resnet-50-panoptic
# 344번 모델 데이터 수집 중입니다.
# facebook/blenderbot-3B
# 345번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-en-ru
# 346번 모델 데이터 수집 중입니다.
# google-bert/bert-large-cased
# 347번 모델 데이터 수집 중입니다.
# allenai/OLMo-7B
# 348번 모델 데이터 수집 중입니다.
# hakurei/waifu-diffusion
# 349번 모델 데이터 수집 중입니다.
# unsloth/llama-3-8b-Instruct-bnb-4bit
# 350번 모델 데이터 수집 중입니다.
# tsmatz/xlm-roberta-ner-japanese
# 351번 모델 데이터 수집 중입니다.
# lmsys/vicuna-13b-v1.5-16k
# 352번 모델 데이터 수집 중입니다.
# sentence-transformers/distiluse-base-multilingual-cased-v1
# 353번 모델 데이터 수집 중입니다.
# laion/CLIP-ViT-bigG-14-laion2B-39B-b160k
# 354번 모델 데이터 수집 중입니다.
# shenzhi-wang/Llama3-8B-Chinese-Chat
# 355번 모델 데이터 수집 중입니다.
# patrickjohncyh/fashion-clip
# 356번 모델 데이터 수집 중입니다.
# OpenGVLab/InternVL-Chat-V1-5
# 357번 모델 데이터 수집 중입니다.
# openchat/openchat-3.5-1210
# 358번 모델 데이터 수집 중입니다.
# kha-white/manga-ocr-base
# 359번 모델 데이터 수집 중입니다.
# Falconsai/text_summarization
# 360번 모델 데이터 수집 중입니다.
# avichr/heBERT_sentiment_analysis
# 361번 모델 데이터 수집 중입니다.
# microsoft/Orca-2-13b
# 362번 모델 데이터 수집 중입니다.
# LanguageBind/Video-LLaVA-7B
# 363번 모델 데이터 수집 중입니다.
# google/mt5-base
# 364번 모델 데이터 수집 중입니다.
# Qwen/Qwen-7B
# 365번 모델 데이터 수집 중입니다.
# GanymedeNil/text2vec-large-chinese
# 366번 모델 데이터 수집 중입니다.
# speechbrain/spkrec-ecapa-voxceleb
# 367번 모델 데이터 수집 중입니다.
# dccuchile/bert-base-spanish-wwm-cased
# 368번 모델 데이터 수집 중입니다.
# ai-forever/rugpt3large_based_on_gpt2
# 369번 모델 데이터 수집 중입니다.
# TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T
# 370번 모델 데이터 수집 중입니다.
# google/deplot
# 371번 모델 데이터 수집 중입니다.
# microsoft/mdeberta-v3-base
# 372번 모델 데이터 수집 중입니다.
# upstage/SOLAR-10.7B-v1.0
# 373번 모델 데이터 수집 중입니다.
# impira/layoutlm-document-qa
# 374번 모델 데이터 수집 중입니다.
# uer/gpt2-chinese-cluecorpussmall
# 375번 모델 데이터 수집 중입니다.
# dmis-lab/biobert-v1.1
# 376번 모델 데이터 수집 중입니다.
# TheBloke/Mistral-7B-Instruct-v0.1-GPTQ
# 377번 모델 데이터 수집 중입니다.
# Intel/dynamic_tinybert
# 378번 모델 데이터 수집 중입니다.
# Babelscape/wikineural-multilingual-ner
# 379번 모델 데이터 수집 중입니다.
# ckiplab/bert-base-chinese-ner
# 380번 모델 데이터 수집 중입니다.
# pszemraj/long-t5-tglobal-base-16384-book-summary
# 381번 모델 데이터 수집 중입니다.
# microsoft/deberta-v3-large
# 382번 모델 데이터 수집 중입니다.
# mistral-community/Mixtral-8x22B-v0.1
# 383번 모델 데이터 수집 중입니다.
# bigscience/bloomz-7b1
# 384번 모델 데이터 수집 중입니다.
# setu4993/LaBSE
# 385번 모델 데이터 수집 중입니다.
# microsoft/layoutlmv2-base-uncased
# 386번 모델 데이터 수집 중입니다.
# bigcode/starcoder2-15b
# 387번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-en-de
# 388번 모델 데이터 수집 중입니다.
# vectara/hallucination_evaluation_model
# 389번 모델 데이터 수집 중입니다.
# moka-ai/m3e-base
# 390번 모델 데이터 수집 중입니다.
# intfloat/multilingual-e5-base
# 391번 모델 데이터 수집 중입니다.
# dbmdz/bert-base-italian-xxl-cased
# 392번 모델 데이터 수집 중입니다.
# stabilityai/stable-diffusion-2-base
# 393번 모델 데이터 수집 중입니다.
# Qwen/Qwen2-72B-Instruct
# 394번 모델 데이터 수집 중입니다.
# mosaicml/mpt-7b-instruct
# 395번 모델 데이터 수집 중입니다.
# Davlan/distilbert-base-multilingual-cased-ner-hrl
# 396번 모델 데이터 수집 중입니다.
# jinaai/jina-embeddings-v2-base-en
# 397번 모델 데이터 수집 중입니다.
# deepseek-ai/deepseek-coder-6.7b-instruct
# 398번 모델 데이터 수집 중입니다.
# dbmdz/bert-base-german-uncased
# 399번 모델 데이터 수집 중입니다.
# segmind/SSD-1B
# 400번 모델 데이터 수집 중입니다.
# NousResearch/Yarn-Mistral-7b-128k
# 401번 모델 데이터 수집 중입니다.
# facebook/opt-2.7b
# 402번 모델 데이터 수집 중입니다.
# fabiochiu/t5-base-tag-generation
# 403번 모델 데이터 수집 중입니다.
# ali-vilab/text-to-video-ms-1.7b
# 404번 모델 데이터 수집 중입니다.
# timpal0l/mdeberta-v3-base-squad2
# 405번 모델 데이터 수집 중입니다.
# jbochi/madlad400-3b-mt
# 406번 모델 데이터 수집 중입니다.
# google/byt5-small
# 407번 모델 데이터 수집 중입니다.
# deepseek-ai/deepseek-coder-33b-instruct
# 408번 모델 데이터 수집 중입니다.
# neuralmind/bert-base-portuguese-cased
# 409번 모델 데이터 수집 중입니다.
# openbmb/MiniCPM-V-2
# 410번 모델 데이터 수집 중입니다.
# monster-labs/control_v1p_sd15_qrcode_monster
# 411번 모델 데이터 수집 중입니다.
# jonatasgrosman/wav2vec2-large-xlsr-53-portuguese
# 412번 모델 데이터 수집 중입니다.
# NousResearch/Hermes-2-Pro-Mistral-7B
# 413번 모델 데이터 수집 중입니다.
# MoritzLaurer/DeBERTa-v3-large-mnli-fever-anli-ling-wanli
# 414번 모델 데이터 수집 중입니다.
# BAAI/bge-base-en-v1.5
# 415번 모델 데이터 수집 중입니다.
# Gryphe/MythoMax-L2-13b
# 416번 모델 데이터 수집 중입니다.
# Supabase/gte-small
# 417번 모델 데이터 수집 중입니다.
# pszemraj/flan-t5-large-grammar-synthesis
# 418번 모델 데이터 수집 중입니다.
# Qwen/Qwen1.5-7B-Chat
# 419번 모델 데이터 수집 중입니다.
# WhereIsAI/UAE-Large-V1
# 420번 모델 데이터 수집 중입니다.
# WarriorMama777/OrangeMixs
# 421번 모델 데이터 수집 중입니다.
# WizardLMTeam/WizardCoder-15B-V1.0
# 422번 모델 데이터 수집 중입니다.
# xlnet/xlnet-base-cased
# 423번 모델 데이터 수집 중입니다.
# stabilityai/stablelm-3b-4e1t
# 424번 모델 데이터 수집 중입니다.
# LumiOpen/Poro-34B
# 425번 모델 데이터 수집 중입니다.
# timm/resnet50.a1_in1k
# 426번 모델 데이터 수집 중입니다.
# TheBloke/Llama-2-13B-chat-GPTQ
# 427번 모델 데이터 수집 중입니다.
# suno/bark-small
# 428번 모델 데이터 수집 중입니다.
# NousResearch/Nous-Hermes-Llama2-13b
# 429번 모델 데이터 수집 중입니다.
# deepset/minilm-uncased-squad2
# 430번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-ko-en
# 431번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-it-en
# 432번 모델 데이터 수집 중입니다.
# Nexusflow/NexusRaven-V2-13B
# 433번 모델 데이터 수집 중입니다.
# cambridgeltl/SapBERT-from-PubMedBERT-fulltext
# 434번 모델 데이터 수집 중입니다.
# ai-forever/ruRoberta-large
# 435번 모델 데이터 수집 중입니다.
# stabilityai/stable-diffusion-3-medium
# 436번 모델 데이터 수집 중입니다.
# facebook/hubert-large-ls960-ft
# 437번 모델 데이터 수집 중입니다.
# microsoft/Phi-3-medium-4k-instruct
# 438번 모델 데이터 수집 중입니다.
# CohereForAI/aya-101
# 439번 모델 데이터 수집 중입니다.
# Qwen/Qwen1.5-0.5B
# 440번 모델 데이터 수집 중입니다.
# Intel/neural-chat-7b-v3-1
# 441번 모델 데이터 수집 중입니다.
# TheBloke/Llama-2-7B-Chat-GPTQ
# 442번 모델 데이터 수집 중입니다.
# microsoft/trocr-small-printed
# 443번 모델 데이터 수집 중입니다.
# bigscience/T0_3B
# 444번 모델 데이터 수집 중입니다.
# microsoft/phi-1
# 445번 모델 데이터 수집 중입니다.
# 01-ai/Yi-6B
# 446번 모델 데이터 수집 중입니다.
# google/vit-base-patch16-384
# 447번 모델 데이터 수집 중입니다.
# 01-ai/Yi-1.5-34B-Chat
# 448번 모델 데이터 수집 중입니다.
# trpakov/vit-face-expression
# 449번 모델 데이터 수집 중입니다.
# sileod/deberta-v3-base-tasksource-nli
# 450번 모델 데이터 수집 중입니다.
# nomic-ai/nomic-embed-text-v1
# 451번 모델 데이터 수집 중입니다.
# cointegrated/rubert-tiny2
# 452번 모델 데이터 수집 중입니다.
# microsoft/table-transformer-structure-recognition-v1.1-all
# 453번 모델 데이터 수집 중입니다.
# bigcode/starcoder
# 454번 모델 데이터 수집 중입니다.
# bigcode/starcoder2-3b
# 455번 모델 데이터 수집 중입니다.
# Qwen/Qwen1.5-72B-Chat
# 456번 모델 데이터 수집 중입니다.
# cognitivecomputations/dolphin-2.9-llama3-8b
# 457번 모델 데이터 수집 중입니다.
# Qwen/Qwen2-7B-Instruct
# 458번 모델 데이터 수집 중입니다.
# stabilityai/sdxl-vae
# 459번 모델 데이터 수집 중입니다.
# laion/larger_clap_general
# 460번 모델 데이터 수집 중입니다.
# amazon/MistralLite
# 461번 모델 데이터 수집 중입니다.
# ByteDance/AnimateDiff-Lightning
# 462번 모델 데이터 수집 중입니다.
# hfl/chinese-bert-wwm-ext
# 463번 모델 데이터 수집 중입니다.
# petals-team/StableBeluga2
# 464번 모델 데이터 수집 중입니다.
# latent-consistency/lcm-lora-sdv1-5
# 465번 모델 데이터 수집 중입니다.
# dandelin/vilt-b32-finetuned-vqa
# 466번 모델 데이터 수집 중입니다.
# T-Systems-onsite/cross-en-de-roberta-sentence-transformer
# 467번 모델 데이터 수집 중입니다.
# adept/fuyu-8b
# 468번 모델 데이터 수집 중입니다.
# stabilityai/stable-diffusion-2-inpainting
# 469번 모델 데이터 수집 중입니다.
# microsoft/swin-tiny-patch4-window7-224
# 470번 모델 데이터 수집 중입니다.
# parler-tts/parler_tts_mini_v0.1
# 471번 모델 데이터 수집 중입니다.
# bigcode/santacoder
# 472번 모델 데이터 수집 중입니다.
# huggyllama/llama-7b
# 473번 모델 데이터 수집 중입니다.
# madebyollin/sdxl-vae-fp16-fix
# 474번 모델 데이터 수집 중입니다.
# cmarkea/distilcamembert-base-ner
# 475번 모델 데이터 수집 중입니다.
# MaziyarPanahi/Mistral-7B-Instruct-v0.3-GGUF
# 476번 모델 데이터 수집 중입니다.
# NousResearch/Nous-Hermes-2-Mixtral-8x7B-DPO
# 477번 모델 데이터 수집 중입니다.
# indolem/indobert-base-uncased
# 478번 모델 데이터 수집 중입니다.
# intfloat/multilingual-e5-small
# 479번 모델 데이터 수집 중입니다.
# mistral-community/Mistral-7B-v0.2
# 480번 모델 데이터 수집 중입니다.
# baichuan-inc/Baichuan2-13B-Chat
# 481번 모델 데이터 수집 중입니다.
# georgesung/llama2_7b_chat_uncensored
# 482번 모델 데이터 수집 중입니다.
# google/vit-large-patch16-224-in21k
# 483번 모델 데이터 수집 중입니다.
# pyannote/wespeaker-voxceleb-resnet34-LM
# 484번 모델 데이터 수집 중입니다.
# THUDM/glm-4-9b-chat
# 485번 모델 데이터 수집 중입니다.
# intfloat/e5-large-v2
# 486번 모델 데이터 수집 중입니다.
# stabilityai/stable-cascade
# 487번 모델 데이터 수집 중입니다.
# cerebras/Cerebras-GPT-13B
# 488번 모델 데이터 수집 중입니다.
# 01-ai/Yi-34B-200K
# 489번 모델 데이터 수집 중입니다.
# tiiuae/falcon-11B
# 490번 모델 데이터 수집 중입니다.
# IDEA-Research/grounding-dino-tiny
# 491번 모델 데이터 수집 중입니다.
# pszemraj/led-large-book-summary
# 492번 모델 데이터 수집 중입니다.
# mrm8488/t5-base-finetuned-question-generation-ap
# 493번 모델 데이터 수집 중입니다.
# nvidia/mit-b0
# 494번 모델 데이터 수집 중입니다.
# SG161222/Realistic_Vision_V4.0_noVAE
# 495번 모델 데이터 수집 중입니다.
# google/owlv2-base-patch16-ensemble
# 496번 모델 데이터 수집 중입니다.
# facebook/dino-vits8
# 497번 모델 데이터 수집 중입니다.
# Snowflake/snowflake-arctic-instruct
# 498번 모델 데이터 수집 중입니다.
# internlm/internlm-xcomposer2-vl-7b
# 499번 모델 데이터 수집 중입니다.
# sonoisa/sentence-bert-base-ja-mean-tokens-v2
# 500번 모델 데이터 수집 중입니다.
# codellama/CodeLlama-13b-Instruct-hf
# 501번 모델 데이터 수집 중입니다.
# vicgalle/xlm-roberta-large-xnli-anli
# 502번 모델 데이터 수집 중입니다.
# aubmindlab/bert-base-arabert
# 503번 모델 데이터 수집 중입니다.
# bigscience/bloom-1b1
# 504번 모델 데이터 수집 중입니다.
# NousResearch/Nous-Hermes-2-Yi-34B
# 505번 모델 데이터 수집 중입니다.
# meta-llama/Llama-2-7b-chat-hf
# 506번 모델 데이터 수집 중입니다.
# cross-encoder/ms-marco-MiniLM-L-6-v2
# 507번 모델 데이터 수집 중입니다.
# JackFram/llama-68m
# 508번 모델 데이터 수집 중입니다.
# NexaAIDev/Octopus-v2
# 509번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-ja-en
# 510번 모델 데이터 수집 중입니다.
# facebook/dino-vitb16
# 511번 모델 데이터 수집 중입니다.
# sadickam/sdg-classification-bert
# 512번 모델 데이터 수집 중입니다.
# af1tang/personaGPT
# 513번 모델 데이터 수집 중입니다.
# microsoft/git-base
# 514번 모델 데이터 수집 중입니다.
# baichuan-inc/Baichuan-13B-Chat
# 515번 모델 데이터 수집 중입니다.
# codellama/CodeLlama-34b-hf
# 516번 모델 데이터 수집 중입니다.
# ByteDance/Hyper-SD
# 517번 모델 데이터 수집 중입니다.
# openai/whisper-medium.en
# 518번 모델 데이터 수집 중입니다.
# gradientai/Llama-3-8B-Instruct-262k
# 519번 모델 데이터 수집 중입니다.
# bigscience/bloom-1b7
# 520번 모델 데이터 수집 중입니다.
# dbmdz/german-gpt2
# 521번 모델 데이터 수집 중입니다.
# stabilityai/stable-video-diffusion-img2vid
# 522번 모델 데이터 수집 중입니다.
# martin-ha/toxic-comment-model
# 523번 모델 데이터 수집 중입니다.
# google/pegasus-xsum
# 524번 모델 데이터 수집 중입니다.
# cointegrated/LaBSE-en-ru
# 525번 모델 데이터 수집 중입니다.
# stabilityai/stablelm-2-zephyr-1_6b
# 526번 모델 데이터 수집 중입니다.
# nvidia/speakerverification_en_titanet_large
# 527번 모델 데이터 수집 중입니다.
# thenlper/gte-small
# 528번 모델 데이터 수집 중입니다.
# microsoft/wavlm-large
# 529번 모델 데이터 수집 중입니다.
# amazon/chronos-t5-tiny
# 530번 모델 데이터 수집 중입니다.
# oliverguhr/german-sentiment-bert
# 531번 모델 데이터 수집 중입니다.
# google/t5-v1_1-xxl
# 532번 모델 데이터 수집 중입니다.
# Qwen/Qwen1.5-0.5B-Chat
# 533번 모델 데이터 수집 중입니다.
# latent-consistency/lcm-lora-sdxl
# 534번 모델 데이터 수집 중입니다.
# SG161222/Realistic_Vision_V5.1_noVAE
# 535번 모델 데이터 수집 중입니다.
# rinna/japanese-gpt-neox-3.6b
# 536번 모델 데이터 수집 중입니다.
# stanford-crfm/BioMedLM
# 537번 모델 데이터 수집 중입니다.
# cognitivecomputations/dolphin-2.1-mistral-7b
# 538번 모델 데이터 수집 중입니다.
# facebook/musicgen-large
# 539번 모델 데이터 수집 중입니다.
# tohoku-nlp/bert-base-japanese-char
# 540번 모델 데이터 수집 중입니다.
# microsoft/mpnet-base
# 541번 모델 데이터 수집 중입니다.
# lucas-leme/FinBERT-PT-BR
# 542번 모델 데이터 수집 중입니다.
# ctheodoris/Geneformer
# 543번 모델 데이터 수집 중입니다.
# bigscience/bloomz-560m
# 544번 모델 데이터 수집 중입니다.
# BAAI/llm-embedder
# 545번 모델 데이터 수집 중입니다.
# defog/sqlcoder-7b-2
# 546번 모델 데이터 수집 중입니다.
# intfloat/e5-mistral-7b-instruct
# 547번 모델 데이터 수집 중입니다.
# amazon/chronos-t5-base
# 548번 모델 데이터 수집 중입니다.
# prompthero/openjourney-v4
# 549번 모델 데이터 수집 중입니다.
# Nexusflow/Starling-LM-7B-beta
# 550번 모델 데이터 수집 중입니다.
# stabilityai/stable-diffusion-2-depth
# 551번 모델 데이터 수집 중입니다.
# togethercomputer/Llama-2-7B-32K-Instruct
# 552번 모델 데이터 수집 중입니다.
# TheBloke/zephyr-7B-beta-AWQ
# 553번 모델 데이터 수집 중입니다.
# savasy/bert-base-turkish-sentiment-cased
# 554번 모델 데이터 수집 중입니다.
# thenlper/gte-large
# 555번 모델 데이터 수집 중입니다.
# core42/jais-13b-chat
# 556번 모델 데이터 수집 중입니다.
# InstantX/InstantID
# 557번 모델 데이터 수집 중입니다.
# OpenAssistant/oasst-sft-4-pythia-12b-epoch-3.5
# 558번 모델 데이터 수집 중입니다.
# prompthero/openjourney
# 559번 모델 데이터 수집 중입니다.
# BioMistral/BioMistral-7B
# 560번 모델 데이터 수집 중입니다.
# beomi/Llama-3-Open-Ko-8B
# 561번 모델 데이터 수집 중입니다.
# SG161222/Realistic_Vision_V2.0
# 562번 모델 데이터 수집 중입니다.
# tner/roberta-large-ontonotes5
# 563번 모델 데이터 수집 중입니다.
# dslim/bert-base-NER-uncased
# 564번 모델 데이터 수집 중입니다.
# pdelobelle/robbert-v2-dutch-base
# 565번 모델 데이터 수집 중입니다.
# cognitivecomputations/WizardLM-7B-Uncensored
# 566번 모델 데이터 수집 중입니다.
# beomi/llama-2-ko-7b
# 567번 모델 데이터 수집 중입니다.
# facebook/bart-large
# 568번 모델 데이터 수집 중입니다.
# SenseTime/deformable-detr
# 569번 모델 데이터 수집 중입니다.
# nomic-ai/gpt4all-falcon
# 570번 모델 데이터 수집 중입니다.
# BAAI/bge-reranker-v2-m3
# 571번 모델 데이터 수집 중입니다.
# bvanaken/clinical-assertion-negation-bert
# 572번 모델 데이터 수집 중입니다.
# meta-llama/Meta-Llama-3-8B-Instruct
# 573번 모델 데이터 수집 중입니다.
# TheBloke/Wizard-Vicuna-13B-Uncensored-GPTQ
# 574번 모델 데이터 수집 중입니다.
# openlm-research/open_llama_3b_v2
# 575번 모델 데이터 수집 중입니다.
# distilbert/distilbert-base-german-cased
# 576번 모델 데이터 수집 중입니다.
# microsoft/Phi-3-small-8k-instruct
# 577번 모델 데이터 수집 중입니다.
# NousResearch/Nous-Hermes-2-SOLAR-10.7B
# 578번 모델 데이터 수집 중입니다.
# LiheYoung/depth_anything_vitl14
# 579번 모델 데이터 수집 중입니다.
# nferruz/ProtGPT2
# 580번 모델 데이터 수집 중입니다.
# IDEA-Research/grounding-dino-base
# 581번 모델 데이터 수집 중입니다.
# shibing624/macbert4csc-base-chinese
# 582번 모델 데이터 수집 중입니다.
# succinctly/text2image-prompt-generator
# 583번 모델 데이터 수집 중입니다.
# stabilityai/stablelm-2-1_6b
# 584번 모델 데이터 수집 중입니다.
# VoVanPhuc/sup-SimCSE-VietNamese-phobert-base
# 585번 모델 데이터 수집 중입니다.
# prajjwal1/bert-small
# 586번 모델 데이터 수집 중입니다.
# sentence-transformers/distilbert-base-nli-stsb-mean-tokens
# 587번 모델 데이터 수집 중입니다.
# Qwen/Qwen-72B
# 588번 모델 데이터 수집 중입니다.
# TheBloke/Llama-2-7B-GGUF
# 589번 모델 데이터 수집 중입니다.
# rinna/japanese-gpt2-medium
# 590번 모델 데이터 수집 중입니다.
# Qwen/CodeQwen1.5-7B-Chat
# 591번 모델 데이터 수집 중입니다.
# stabilityai/StableBeluga2
# 592번 모델 데이터 수집 중입니다.
# BAAI/bge-reranker-base
# 593번 모델 데이터 수집 중입니다.
# facebook/xlm-roberta-xl
# 594번 모델 데이터 수집 중입니다.
# WinKawaks/vit-tiny-patch16-224
# 595번 모델 데이터 수집 중입니다.
# databricks/dbrx-instruct
# 596번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-en-ar
# 597번 모델 데이터 수집 중입니다.
# climatebert/distilroberta-base-climate-detector
# 598번 모델 데이터 수집 중입니다.
# sentence-transformers/all-distilroberta-v1
# 599번 모델 데이터 수집 중입니다.
# diffusers/stable-diffusion-xl-1.0-inpainting-0.1
# 600번 모델 데이터 수집 중입니다.
# Qwen/Qwen1.5-32B-Chat
# 601번 모델 데이터 수집 중입니다.
# MCG-NJU/videomae-base-finetuned-kinetics
# 602번 모델 데이터 수집 중입니다.
# jonatasgrosman/wav2vec2-large-xlsr-53-japanese
# 603번 모델 데이터 수집 중입니다.
# sentence-transformers/clip-ViT-B-32-multilingual-v1
# 604번 모델 데이터 수집 중입니다.
# Deci/DeciCoder-1b
# 605번 모델 데이터 수집 중입니다.
# stabilityai/stable-diffusion-x4-upscaler
# 606번 모델 데이터 수집 중입니다.
# THUDM/cogvlm-chat-hf
# 607번 모델 데이터 수집 중입니다.
# kingabzpro/wav2vec2-large-xls-r-300m-Urdu
# 608번 모델 데이터 수집 중입니다.
# stabilityai/stablelm-zephyr-3b
# 609번 모델 데이터 수집 중입니다.
# dbmdz/bert-base-turkish-uncased
# 610번 모델 데이터 수집 중입니다.
# facebook/blenderbot-400M-distill
# 611번 모델 데이터 수집 중입니다.
# ufal/robeczech-base
# 612번 모델 데이터 수집 중입니다.
# Salesforce/codet5p-110m-embedding
# 613번 모델 데이터 수집 중입니다.
# facebook/maskformer-swin-base-coco
# 614번 모델 데이터 수집 중입니다.
# TheBloke/Mixtral-8x7B-v0.1-GGUF
# 615번 모델 데이터 수집 중입니다.
# DiscoResearch/mixtral-7b-8expert
# 616번 모델 데이터 수집 중입니다.
# meta-llama/Meta-Llama-3-8B
# 617번 모델 데이터 수집 중입니다.
# facebook/blenderbot_small-90M
# 618번 모델 데이터 수집 중입니다.
# cognitivecomputations/dolphin-2.2.1-mistral-7b
# 619번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-tr-en
# 620번 모델 데이터 수집 중입니다.
# THUDM/cogvlm2-llama3-chat-19B
# 621번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-pl-en
# 622번 모델 데이터 수집 중입니다.
# LanguageBind/MoE-LLaVA-Phi2-2.7B-4e
# 623번 모델 데이터 수집 중입니다.
# cagliostrolab/animagine-xl-3.0
# 624번 모델 데이터 수집 중입니다.
# allenai/specter2_base
# 625번 모델 데이터 수집 중입니다.
# pankajmathur/orca_mini_3b
# 626번 모델 데이터 수집 중입니다.
# facebook/w2v-bert-2.0
# 627번 모델 데이터 수집 중입니다.
# lmsys/vicuna-7b-v1.3
# 628번 모델 데이터 수집 중입니다.
# TheBloke/phi-2-GGUF
# 629번 모델 데이터 수집 중입니다.
# sentence-transformers/paraphrase-mpnet-base-v2
# 630번 모델 데이터 수집 중입니다.
# DeepPavlov/rubert-base-cased
# 631번 모델 데이터 수집 중입니다.
# internlm/internlm2-chat-7b
# 632번 모델 데이터 수집 중입니다.
# TheBloke/deepseek-coder-33B-instruct-GPTQ
# 633번 모델 데이터 수집 중입니다.
# lmsys/vicuna-33b-v1.3
# 634번 모델 데이터 수집 중입니다.
# allenai/specter
# 635번 모델 데이터 수집 중입니다.
# M-CLIP/XLM-Roberta-Large-Vit-B-32
# 636번 모델 데이터 수집 중입니다.
# yiyanghkust/finbert-esg-9-categories
# 637번 모델 데이터 수집 중입니다.
# TheBloke/Llama-2-7B-Chat-GGML
# 638번 모델 데이터 수집 중입니다.
# primeline/whisper-large-v3-german
# 639번 모델 데이터 수집 중입니다.
# TheBloke/Llama-2-70B-Chat-GPTQ
# 640번 모델 데이터 수집 중입니다.
# mistralai/Mistral-7B-Instruct-v0.3
# 641번 모델 데이터 수집 중입니다.
# playgroundai/playground-v2.5-1024px-aesthetic
# 642번 모델 데이터 수집 중입니다.
# TheBloke/Llama-2-7B-fp16
# 643번 모델 데이터 수집 중입니다.
# cross-encoder/nli-roberta-base
# 644번 모델 데이터 수집 중입니다.
# magorshunov/layoutlm-invoices
# 645번 모델 데이터 수집 중입니다.
# chavinlo/gpt4-x-alpaca
# 646번 모델 데이터 수집 중입니다.
# Salesforce/xgen-7b-8k-base
# 647번 모델 데이터 수집 중입니다.
# Salesforce/blip2-flan-t5-xl
# 648번 모델 데이터 수집 중입니다.
# nomic-ai/gpt4all-j
# 649번 모델 데이터 수집 중입니다.
# Open-Orca/OpenOrca-Platypus2-13B
# 650번 모델 데이터 수집 중입니다.
# cagliostrolab/animagine-xl-3.1
# 651번 모델 데이터 수집 중입니다.
# tuner007/pegasus_paraphrase
# 652번 모델 데이터 수집 중입니다.
# vinai/phobert-base-v2
# 653번 모델 데이터 수집 중입니다.
# shenzhi-wang/Llama3-8B-Chinese-Chat-GGUF-8bit
# 654번 모델 데이터 수집 중입니다.
# Lin-Chen/ShareCaptioner
# 655번 모델 데이터 수집 중입니다.
# internlm/internlm2-chat-20b
# 656번 모델 데이터 수집 중입니다.
# YituTech/conv-bert-base
# 657번 모델 데이터 수집 중입니다.
# NousResearch/Nous-Hermes-2-Mistral-7B-DPO
# 658번 모델 데이터 수집 중입니다.
# bigscience/bloomz-7b1-mt
# 659번 모델 데이터 수집 중입니다.
# playgroundai/playground-v2-1024px-aesthetic
# 660번 모델 데이터 수집 중입니다.
# albert/albert-large-v2
# 661번 모델 데이터 수집 중입니다.
# miqudev/miqu-1-70b
# 662번 모델 데이터 수집 중입니다.
# facebook/galactica-125m
# 663번 모델 데이터 수집 중입니다.
# Qwen/Qwen1.5-14B-Chat
# 664번 모델 데이터 수집 중입니다.
# abacusai/Smaug-72B-v0.1
# 665번 모델 데이터 수집 중입니다.
# smallcloudai/Refact-1_6B-fim
# 666번 모델 데이터 수집 중입니다.
# WhiteRabbitNeo/WhiteRabbitNeo-13B-v1
# 667번 모델 데이터 수집 중입니다.
# OpenAssistant/reward-model-deberta-v3-large-v2
# 668번 모델 데이터 수집 중입니다.
# jackhhao/jailbreak-classifier
# 669번 모델 데이터 수집 중입니다.
# m-a-p/OpenCodeInterpreter-DS-6.7B
# 670번 모델 데이터 수집 중입니다.
# NousResearch/Meta-Llama-3-8B-Instruct
# 671번 모델 데이터 수집 중입니다.
# openai/whisper-small.en
# 672번 모델 데이터 수집 중입니다.
# speechbrain/lang-id-voxlingua107-ecapa
# 673번 모델 데이터 수집 중입니다.
# cross-encoder/ms-marco-MiniLM-L-12-v2
# 674번 모델 데이터 수집 중입니다.
# Qwen/Qwen-14B
# 675번 모델 데이터 수집 중입니다.
# gsdf/Counterfeit-V2.5
# 676번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-sv-en
# 677번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-nl-en
# 678번 모델 데이터 수집 중입니다.
# rinna/japanese-gpt-1b
# 679번 모델 데이터 수집 중입니다.
# wukevin/tcr-bert
# 680번 모델 데이터 수집 중입니다.
# facebook/mask2former-swin-base-coco-panoptic
# 681번 모델 데이터 수집 중입니다.
# NousResearch/Meta-Llama-3-8B
# 682번 모델 데이터 수집 중입니다.
# TencentARC/PhotoMaker
# 683번 모델 데이터 수집 중입니다.
# protectai/deberta-v3-base-prompt-injection
# 684번 모델 데이터 수집 중입니다.
# elyza/ELYZA-japanese-Llama-2-7b-instruct
# 685번 모델 데이터 수집 중입니다.
# ai4bharat/indictrans2-indic-en-1B
# 686번 모델 데이터 수집 중입니다.
# teknium/OpenHermes-2-Mistral-7B
# 687번 모델 데이터 수집 중입니다.
# albert/albert-xxlarge-v2
# 688번 모델 데이터 수집 중입니다.
# aubmindlab/bert-base-arabertv02
# 689번 모델 데이터 수집 중입니다.
# intfloat/e5-base-v2
# 690번 모델 데이터 수집 중입니다.
# thenlper/gte-base
# 691번 모델 데이터 수집 중입니다.
# nitrosocke/Ghibli-Diffusion
# 692번 모델 데이터 수집 중입니다.
# Rostlab/prot_t5_xl_uniref50
# 693번 모델 데이터 수집 중입니다.
# 01-ai/Yi-6B-200K
# 694번 모델 데이터 수집 중입니다.
# vinvino02/glpn-nyu
# 695번 모델 데이터 수집 중입니다.
# mixedbread-ai/mxbai-rerank-large-v1
# 696번 모델 데이터 수집 중입니다.
# NbAiLab/nb-wav2vec2-300m-nynorsk
# 697번 모델 데이터 수집 중입니다.
# trl-internal-testing/tiny-random-LlamaForCausalLM
# 698번 모델 데이터 수집 중입니다.
# grammarly/coedit-large
# 699번 모델 데이터 수집 중입니다.
# jinaai/jina-colbert-v1-en
# 700번 모델 데이터 수집 중입니다.
# state-spaces/mamba-2.8b
# 701번 모델 데이터 수집 중입니다.
# pyannote/segmentation-3.0
# 702번 모델 데이터 수집 중입니다.
# stabilityai/sd-turbo
# 703번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-en-hi
# 704번 모델 데이터 수집 중입니다.
# deepseek-ai/DeepSeek-V2-Chat
# 705번 모델 데이터 수집 중입니다.
# hfl/chinese-roberta-wwm-ext
# 706번 모델 데이터 수집 중입니다.
# facebook/sam-vit-large
# 707번 모델 데이터 수집 중입니다.
# princeton-nlp/Sheared-LLaMA-1.3B
# 708번 모델 데이터 수집 중입니다.
# rinna/japanese-roberta-base
# 709번 모델 데이터 수집 중입니다.
# microsoft/layoutxlm-base
# 710번 모델 데이터 수집 중입니다.
# baichuan-inc/Baichuan2-7B-Chat
# 711번 모델 데이터 수집 중입니다.
# microsoft/deberta-large-mnli
# 712번 모델 데이터 수집 중입니다.
# GroNLP/bert-base-dutch-cased
# 713번 모델 데이터 수집 중입니다.
# shahrukhx01/question-vs-statement-classifier
# 714번 모델 데이터 수집 중입니다.
# meta-llama/Llama-2-7b-hf
# 715번 모델 데이터 수집 중입니다.
# facebook/dinov2-large
# 716번 모델 데이터 수집 중입니다.
# SanctumAI/Meta-Llama-3-8B-Instruct-GGUF
# 717번 모델 데이터 수집 중입니다.
# facebook/wav2vec2-base
# 718번 모델 데이터 수집 중입니다.
# microsoft/kosmos-2-patch14-224
# 719번 모델 데이터 수집 중입니다.
# togethercomputer/StripedHyena-Nous-7B
# 720번 모델 데이터 수집 중입니다.
# unum-cloud/uform-gen2-qwen-500m
# 721번 모델 데이터 수집 중입니다.
# microsoft/Orca-2-7b
# 722번 모델 데이터 수집 중입니다.
# TencentGameMate/chinese-hubert-base
# 723번 모델 데이터 수집 중입니다.
# microsoft/biogpt
# 724번 모델 데이터 수집 중입니다.
# Qwen/Qwen-VL
# 725번 모델 데이터 수집 중입니다.
# zhihan1996/DNABERT-2-117M
# 726번 모델 데이터 수집 중입니다.
# alpindale/WizardLM-2-8x22B
# 727번 모델 데이터 수집 중입니다.
# BAAI/bge-base-en
# 728번 모델 데이터 수집 중입니다.
# facebook/wav2vec2-xls-r-300m
# 729번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-en-it
# 730번 모델 데이터 수집 중입니다.
# Salesforce/blip2-flan-t5-xxl
# 731번 모델 데이터 수집 중입니다.
# LiheYoung/depth-anything-small-hf
# 732번 모델 데이터 수집 중입니다.
# Deci/DeciLM-7B
# 733번 모델 데이터 수집 중입니다.
# nerijs/pixel-art-xl
# 734번 모델 데이터 수집 중입니다.
# oliverguhr/spelling-correction-english-base
# 735번 모델 데이터 수집 중입니다.
# immich-app/ViT-B-32__openai
# 736번 모델 데이터 수집 중입니다.
# microsoft/deberta-v3-small
# 737번 모델 데이터 수집 중입니다.
# fxmarty/tiny-llama-fast-tokenizer
# 738번 모델 데이터 수집 중입니다.
# pyannote/speaker-diarization-3.1
# 739번 모델 데이터 수집 중입니다.
# codellama/CodeLlama-7b-Python-hf
# 740번 모델 데이터 수집 중입니다.
# llm-blender/PairRM
# 741번 모델 데이터 수집 중입니다.
# TheBloke/LLaMA2-13B-Tiefighter-GPTQ
# 742번 모델 데이터 수집 중입니다.
# dataautogpt3/OpenDalleV1.1
# 743번 모델 데이터 수집 중입니다.
# hustvl/yolos-base
# 744번 모델 데이터 수집 중입니다.
# tiiuae/falcon-rw-1b
# 745번 모델 데이터 수집 중입니다.
# casperhansen/llama-3-70b-instruct-awq
# 746번 모델 데이터 수집 중입니다.
# myshell-ai/MeloTTS-Chinese
# 747번 모델 데이터 수집 중입니다.
# internlm/internlm2-20b
# 748번 모델 데이터 수집 중입니다.
# rinna/japanese-clip-vit-b-16
# 749번 모델 데이터 수집 중입니다.
# TheBloke/OpenHermes-2.5-Mistral-7B-GGUF
# 750번 모델 데이터 수집 중입니다.
# cointegrated/rubert-tiny-toxicity
# 751번 모델 데이터 수집 중입니다.
# naver/splade-cocondenser-ensembledistil
# 752번 모델 데이터 수집 중입니다.
# codellama/CodeLlama-70b-hf
# 753번 모델 데이터 수집 중입니다.
# deepseek-ai/DeepSeek-V2
# 754번 모델 데이터 수집 중입니다.
# aaditya/Llama3-OpenBioLLM-70B
# 755번 모델 데이터 수집 중입니다.
# TheBloke/Llama-2-13B-chat-GGUF
# 756번 모델 데이터 수집 중입니다.
# sshleifer/tiny-gpt2
# 757번 모델 데이터 수집 중입니다.
# bigcode/starcoder2-7b
# 758번 모델 데이터 수집 중입니다.
# sentence-transformers/paraphrase-MiniLM-L3-v2
# 759번 모델 데이터 수집 중입니다.
# Salesforce/blip-vqa-capfilt-large
# 760번 모델 데이터 수집 중입니다.
# TheBloke/TinyLlama-1.1B-Chat-v1.0-GGUF
# 761번 모델 데이터 수집 중입니다.
# m3rg-iitd/matscibert
# 762번 모델 데이터 수집 중입니다.
# NousResearch/Llama-2-13b-hf
# 763번 모델 데이터 수집 중입니다.
# SimianLuo/LCM_Dreamshaper_v7
# 764번 모델 데이터 수집 중입니다.
# WizardLMTeam/WizardLM-70B-V1.0
# 765번 모델 데이터 수집 중입니다.
# openai/whisper-base.en
# 766번 모델 데이터 수집 중입니다.
# TheBloke/Mistral-7B-OpenOrca-GGUF
# 767번 모델 데이터 수집 중입니다.
# deepseek-ai/deepseek-vl-7b-chat
# 768번 모델 데이터 수집 중입니다.
# dreamlike-art/dreamlike-photoreal-2.0
# 769번 모델 데이터 수집 중입니다.
# SG161222/Realistic_Vision_V6.0_B1_noVAE
# 770번 모델 데이터 수집 중입니다.
# cardiffnlp/tweet-topic-21-multi
# 771번 모델 데이터 수집 중입니다.
# ahxt/LiteLlama-460M-1T
# 772번 모델 데이터 수집 중입니다.
# VAGOsolutions/SauerkrautLM-Mixtral-8x7B-Instruct
# 773번 모델 데이터 수집 중입니다.
# google-bert/bert-large-uncased-whole-word-masking
# 774번 모델 데이터 수집 중입니다.
# facebook/encodec_32khz
# 775번 모델 데이터 수집 중입니다.
# indobenchmark/indobert-base-p1
# 776번 모델 데이터 수집 중입니다.
# NousResearch/Nous-Capybara-34B
# 777번 모델 데이터 수집 중입니다.
# intfloat/multilingual-e5-large-instruct
# 778번 모델 데이터 수집 중입니다.
# SG161222/Realistic_Vision_V1.4
# 779번 모델 데이터 수집 중입니다.
# cardiffnlp/twitter-roberta-base-offensive
# 780번 모델 데이터 수집 중입니다.
# facebook/mask2former-swin-large-cityscapes-semantic
# 781번 모델 데이터 수집 중입니다.
# TheBloke/Mistral-7B-v0.1-GGUF
# 782번 모델 데이터 수집 중입니다.
# cmarkea/distilcamembert-base
# 783번 모델 데이터 수집 중입니다.
# 152334H/miqu-1-70b-sf
# 784번 모델 데이터 수집 중입니다.
# ai-forever/rugpt3small_based_on_gpt2
# 785번 모델 데이터 수집 중입니다.
# HuggingFaceM4/tiny-random-LlamaForCausalLM
# 786번 모델 데이터 수집 중입니다.
# cerspense/zeroscope_v2_576w
# 787번 모델 데이터 수집 중입니다.
# OrdalieTech/Solon-embeddings-large-0.1
# 788번 모델 데이터 수집 중입니다.
# mosaicml/mpt-30b-chat
# 789번 모델 데이터 수집 중입니다.
# 2Noise/ChatTTS
# 790번 모델 데이터 수집 중입니다.
# Systran/faster-whisper-large-v3
# 791번 모델 데이터 수집 중입니다.
# TinyLlama/TinyLlama-1.1B-Chat-v0.6
# 792번 모델 데이터 수집 중입니다.
# michellejieli/emotion_text_classifier
# 793번 모델 데이터 수집 중입니다.
# intfloat/e5-small-v2
# 794번 모델 데이터 수집 중입니다.
# roborovski/superprompt-v1
# 795번 모델 데이터 수집 중입니다.
# FlagAlpha/Llama2-Chinese-13b-Chat
# 796번 모델 데이터 수집 중입니다.
# ai-forever/ruBert-base
# 797번 모델 데이터 수집 중입니다.
# aaditya/Llama3-OpenBioLLM-8B
# 798번 모델 데이터 수집 중입니다.
# microsoft/beit-base-patch16-224
# 799번 모델 데이터 수집 중입니다.
# OpenAssistant/oasst-rm-2-pythia-6.9b-epoch-1
# 800번 모델 데이터 수집 중입니다.
# FlagAlpha/Llama2-Chinese-7b-Chat
# 801번 모델 데이터 수집 중입니다.
# medalpaca/medalpaca-7b
# 802번 모델 데이터 수집 중입니다.
# microsoft/Phi-3-small-128k-instruct
# 803번 모델 데이터 수집 중입니다.
# facebook/dpr-ctx_encoder-single-nq-base
# 804번 모델 데이터 수집 중입니다.
# PygmalionAI/pygmalion-6b
# 805번 모델 데이터 수집 중입니다.
# JujoHotaru/lora
# 806번 모델 데이터 수집 중입니다.
# distil-whisper/distil-small.en
# 807번 모델 데이터 수집 중입니다.
# facebook/dpr-question_encoder-single-nq-base
# 808번 모델 데이터 수집 중입니다.
# codellama/CodeLlama-13b-hf
# 809번 모델 데이터 수집 중입니다.
# obi/deid_roberta_i2b2
# 810번 모델 데이터 수집 중입니다.
# ehsanaghaei/SecureBERT
# 811번 모델 데이터 수집 중입니다.
# sentence-transformers/stsb-xlm-r-multilingual
# 812번 모델 데이터 수집 중입니다.
# sentence-transformers/msmarco-distilbert-base-tas-b
# 813번 모델 데이터 수집 중입니다.
# tohoku-nlp/bert-base-japanese-char-whole-word-masking
# 814번 모델 데이터 수집 중입니다.
# akdeniz27/bert-base-turkish-cased-ner
# 815번 모델 데이터 수집 중입니다.
# EleutherAI/pythia-70m-deduped
# 816번 모델 데이터 수집 중입니다.
# microsoft/wavlm-base-plus
# 817번 모델 데이터 수집 중입니다.
# Qwen/Qwen-14B-Chat
# 818번 모델 데이터 수집 중입니다.
# facebook/wav2vec2-xls-r-1b
# 819번 모델 데이터 수집 중입니다.
# lmsys/vicuna-13b-delta-v1.1
# 820번 모델 데이터 수집 중입니다.
# huggingface/CodeBERTa-language-id
# 821번 모델 데이터 수집 중입니다.
# facebook/nllb-200-3.3B
# 822번 모델 데이터 수집 중입니다.
# cmarkea/distilcamembert-base-sentiment
# 823번 모델 데이터 수집 중입니다.
# stabilityai/stablelm-base-alpha-7b
# 824번 모델 데이터 수집 중입니다.
# lmsys/vicuna-13b-v1.3
# 825번 모델 데이터 수집 중입니다.
# cognitivecomputations/Wizard-Vicuna-13B-Uncensored
# 826번 모델 데이터 수집 중입니다.
# beomi/KoAlpaca-Polyglot-12.8B
# 827번 모델 데이터 수집 중입니다.
# TheBloke/Mistral-7B-v0.1-AWQ
# 828번 모델 데이터 수집 중입니다.
# bhadresh-savani/distilbert-base-uncased-emotion
# 829번 모델 데이터 수집 중입니다.
# TheBloke/MythoMax-L2-13B-GPTQ
# 830번 모델 데이터 수집 중입니다.
# TheBloke/zephyr-7B-beta-GGUF
# 831번 모델 데이터 수집 중입니다.
# malteos/scincl
# 832번 모델 데이터 수집 중입니다.
# CausalLM/14B
# 833번 모델 데이터 수집 중입니다.
# internlm/internlm2-7b
# 834번 모델 데이터 수집 중입니다.
# JackFram/llama-160m
# 835번 모델 데이터 수집 중입니다.
# core42/jais-13b
# 836번 모델 데이터 수집 중입니다.
# facebook/flava-full
# 837번 모델 데이터 수집 중입니다.
# LanguageBind/LanguageBind_Image
# 838번 모델 데이터 수집 중입니다.
# HuggingFaceM4/idefics-9b-instruct
# 839번 모델 데이터 수집 중입니다.
# ise-uiuc/Magicoder-S-DS-6.7B
# 840번 모델 데이터 수집 중입니다.
# llava-hf/vip-llava-7b-hf
# 841번 모델 데이터 수집 중입니다.
# BAAI/bge-large-zh
# 842번 모델 데이터 수집 중입니다.
# GritLM/GritLM-7B
# 843번 모델 데이터 수집 중입니다.
# TheBloke/dolphin-2.5-mixtral-8x7b-GGUF
# 844번 모델 데이터 수집 중입니다.
# google/canine-s
# 845번 모델 데이터 수집 중입니다.
# Hate-speech-CNERG/bert-base-uncased-hatexplain
# 846번 모델 데이터 수집 중입니다.
# facebook/wav2vec2-large-960h-lv60-self
# 847번 모델 데이터 수집 중입니다.
# AI4PD/ZymCTRL
# 848번 모델 데이터 수집 중입니다.
# UrukHan/t5-russian-spell
# 849번 모델 데이터 수집 중입니다.
# Qwen/Qwen1.5-110B-Chat
# 850번 모델 데이터 수집 중입니다.
# mosaicml/mpt-30b-instruct
# 851번 모델 데이터 수집 중입니다.
# mistralai/Mixtral-8x22B-Instruct-v0.1
# 852번 모델 데이터 수집 중입니다.
# HuggingFaceH4/zephyr-orpo-141b-A35b-v0.1
# 853번 모델 데이터 수집 중입니다.
# hkunlp/instructor-large
# 854번 모델 데이터 수집 중입니다.
# unitary/unbiased-toxic-roberta
# 855번 모델 데이터 수집 중입니다.
# Salesforce/blip2-opt-6.7b
# 856번 모델 데이터 수집 중입니다.
# sentence-transformers/sentence-t5-large
# 857번 모델 데이터 수집 중입니다.
# PixArt-alpha/PixArt-XL-2-1024-MS
# 858번 모델 데이터 수집 중입니다.
# microsoft/tapex-large-finetuned-wtq
# 859번 모델 데이터 수집 중입니다.
# TinyLlama/TinyLlama-1.1B-step-50K-105b
# 860번 모델 데이터 수집 중입니다.
# google/owlvit-large-patch14
# 861번 모델 데이터 수집 중입니다.
# Voicelab/vlt5-base-keywords
# 862번 모델 데이터 수집 중입니다.
# ml6team/keyphrase-extraction-kbir-inspec
# 863번 모델 데이터 수집 중입니다.
# Alibaba-NLP/gte-base-en-v1.5
# 864번 모델 데이터 수집 중입니다.
# cardiffnlp/twitter-xlm-roberta-base-sentiment-multilingual
# 865번 모델 데이터 수집 중입니다.
# amazon/chronos-t5-small
# 866번 모델 데이터 수집 중입니다.
# facebook/mask2former-swin-large-ade-semantic
# 867번 모델 데이터 수집 중입니다.
# liuhaotian/llava-v1.6-34b
# 868번 모델 데이터 수집 중입니다.
# TheBloke/Llama-2-7B-GPTQ
# 869번 모델 데이터 수집 중입니다.
# jonatasgrosman/wav2vec2-large-xlsr-53-arabic
# 870번 모델 데이터 수집 중입니다.
# Falconsai/intent_classification
# 871번 모델 데이터 수집 중입니다.
# Copycats/koelectra-base-v3-generalized-sentiment-analysis
# 872번 모델 데이터 수집 중입니다.
# cognitivecomputations/dolphin-2.8-mistral-7b-v02
# 873번 모델 데이터 수집 중입니다.
# naver-clova-ix/donut-base
# 874번 모델 데이터 수집 중입니다.
# TheBloke/Wizard-Vicuna-30B-Uncensored-GPTQ
# 875번 모델 데이터 수집 중입니다.
# EleutherAI/pythia-160m
# 876번 모델 데이터 수집 중입니다.
# stabilityai/sd-vae-ft-mse
# 877번 모델 데이터 수집 중입니다.
# lucyknada/microsoft_WizardLM-2-7B
# 878번 모델 데이터 수집 중입니다.
# TheBloke/Phind-CodeLlama-34B-v2-GGUF
# 879번 모델 데이터 수집 중입니다.
# TheBloke/Wizard-Vicuna-7B-Uncensored-GPTQ
# 880번 모델 데이터 수집 중입니다.
# dbmdz/bert-base-german-cased
# 881번 모델 데이터 수집 중입니다.
# lmms-lab/llama3-llava-next-8b
# 882번 모델 데이터 수집 중입니다.
# hfl/chinese-alpaca-2-7b
# 883번 모델 데이터 수집 중입니다.
# facebook/nllb-200-1.3B
# 884번 모델 데이터 수집 중입니다.
# codellama/CodeLlama-70b-Instruct-hf
# 885번 모델 데이터 수집 중입니다.
# DeepFloyd/t5-v1_1-xxl
# 886번 모델 데이터 수집 중입니다.
# stabilityai/StableBeluga-7B
# 887번 모델 데이터 수집 중입니다.
# w11wo/indonesian-roberta-base-posp-tagger
# 888번 모델 데이터 수집 중입니다.
# TheBloke/deepseek-coder-6.7B-instruct-GGUF
# 889번 모델 데이터 수집 중입니다.
# Qwen/Qwen1.5-MoE-A2.7B
# 890번 모델 데이터 수집 중입니다.
# togethercomputer/GPT-JT-6B-v1
# 891번 모델 데이터 수집 중입니다.
# benjamin/wtp-canine-s-1l
# 892번 모델 데이터 수집 중입니다.
# Qwen/Qwen1.5-7B
# 893번 모델 데이터 수집 중입니다.
# bdsqlsz/qinglong_controlnet-lllite
# 894번 모델 데이터 수집 중입니다.
# neulab/codebert-python
# 895번 모델 데이터 수집 중입니다.
# facebook/opt-6.7b
# 896번 모델 데이터 수집 중입니다.
# valhalla/t5-base-e2e-qg
# 897번 모델 데이터 수집 중입니다.
# MLP-KTLim/llama-3-Korean-Bllossom-8B
# 898번 모델 데이터 수집 중입니다.
# LiheYoung/depth-anything-large-hf
# 899번 모델 데이터 수집 중입니다.
# apple/mobilevit-small
# 900번 모델 데이터 수집 중입니다.
# Michau/t5-base-en-generate-headline
# 901번 모델 데이터 수집 중입니다.
# diffusers/controlnet-canny-sdxl-1.0
# 902번 모델 데이터 수집 중입니다.
# TheBloke/Mistral-7B-Instruct-v0.2-AWQ
# 903번 모델 데이터 수집 중입니다.
# EleutherAI/llemma_7b
# 904번 모델 데이터 수집 중입니다.
# sentence-transformers/sentence-t5-base
# 905번 모델 데이터 수집 중입니다.
# google/t5-v1_1-xl
# 906번 모델 데이터 수집 중입니다.
# xlnet/xlnet-large-cased
# 907번 모델 데이터 수집 중입니다.
# Qwen/Qwen1.5-1.8B
# 908번 모델 데이터 수집 중입니다.
# google/pix2struct-large
# 909번 모델 데이터 수집 중입니다.
# dreamlike-art/dreamlike-diffusion-1.0
# 910번 모델 데이터 수집 중입니다.
# facebook/esm2_t6_8M_UR50D
# 911번 모델 데이터 수집 중입니다.
# knkarthick/MEETING_SUMMARY
# 912번 모델 데이터 수집 중입니다.
# unsloth/mistral-7b-instruct-v0.2-bnb-4bit
# 913번 모델 데이터 수집 중입니다.
# deepseek-ai/deepseek-coder-6.7b-base
# 914번 모델 데이터 수집 중입니다.
# THUDM/glm-4v-9b
# 915번 모델 데이터 수집 중입니다.
# neuralmind/bert-large-portuguese-cased
# 916번 모델 데이터 수집 중입니다.
# unicamp-dl/ptt5-base-portuguese-vocab
# 917번 모델 데이터 수집 중입니다.
# ai-forever/ruGPT-3.5-13B
# 918번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-en-id
# 919번 모델 데이터 수집 중입니다.
# MoritzLaurer/multilingual-MiniLMv2-L6-mnli-xnli
# 920번 모델 데이터 수집 중입니다.
# sentence-transformers/msmarco-bert-base-dot-v5
# 921번 모델 데이터 수집 중입니다.
# openlm-research/open_llama_13b
# 922번 모델 데이터 수집 중입니다.
# microsoft/deberta-v2-xlarge-mnli
# 923번 모델 데이터 수집 중입니다.
# TheBloke/CodeLlama-7B-Instruct-GGUF
# 924번 모델 데이터 수집 중입니다.
# MoritzLaurer/deberta-v3-large-zeroshot-v2.0
# 925번 모델 데이터 수집 중입니다.
# hfl/chinese-macbert-base
# 926번 모델 데이터 수집 중입니다.
# mlabonne/NeuralDaredevil-7B
# 927번 모델 데이터 수집 중입니다.
# sentence-transformers/multi-qa-distilbert-cos-v1
# 928번 모델 데이터 수집 중입니다.
# uer/roberta-base-chinese-extractive-qa
# 929번 모델 데이터 수집 중입니다.
# 01-ai/Yi-1.5-9B-Chat
# 930번 모델 데이터 수집 중입니다.
# ...
# 9714번 모델 데이터 수집 중입니다.
# llm-blender/PairRM-hf
# 9715번 모델 데이터 수집 중입니다.
# Mihaiii/Metis-0.3
# 9716번 모델 데이터 수집 중입니다.
# facebook/convnextv2-large-22k-384
# 9717번 모델 데이터 수집 중입니다.
# PistachioAlt/Noromaid-Bagel-7B-Slerp
# 9718번 모델 데이터 수집 중입니다.
# diffnamehard/Psyfighter2-Noromaid-ties-13B
# 9719번 모델 데이터 수집 중입니다.
# AIGym/deepseek-coder-6.7b-chat
# 9720번 모델 데이터 수집 중입니다.
# edbeeching/decision-transformer-gym-hopper-expert
# 9721번 모델 데이터 수집 중입니다.
# bhadresh-savani/roberta-base-emotion
# 9722번 모델 데이터 수집 중입니다.
# s3nh/Mistral_Sonyichi-7B-slerp
# 9723번 모델 데이터 수집 중입니다.
# TheDrummer/Moistral-11B-v4-GGUF
# 9724번 모델 데이터 수집 중입니다.
# duyntnet/Delexa-Instruct-V0.1-7b-imatrix-GGUF
# 9725번 모델 데이터 수집 중입니다.
# Walmart-the-bag/Misted-v2-7B
# 9726번 모델 데이터 수집 중입니다.
# lodrick-the-lafted/Hermes-Instruct-7B-v0.2
# 9727번 모델 데이터 수집 중입니다.
# Akashpb13/Central_kurdish_xlsr
# 9728번 모델 데이터 수집 중입니다.
# Unbabel/gec-t5_small
# 9729번 모델 데이터 수집 중입니다.
# Lajonbot/Llama-2-7b-chat-hf-instruct-pl-lora_unload
# 9730번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-ga-en
# 9731번 모델 데이터 수집 중입니다.
# mrm8488/bert2bert_shared-turkish-summarization
# 9732번 모델 데이터 수집 중입니다.
# tscholak/cxmefzzi
# 9733번 모델 데이터 수집 중입니다.
# mlabonne/Mistralpaca-7B
# 9734번 모델 데이터 수집 중입니다.
# TheBloke/SauerkrautLM-Mixtral-8x7B-Instruct-AWQ
# 9735번 모델 데이터 수집 중입니다.
# Weyaxi/Einstein-v3-7B
# 9736번 모델 데이터 수집 중입니다.
# Lajonbot/WizardLM-13B-V1.2-PL-lora_unload
# 9737번 모델 데이터 수집 중입니다.
# MaziyarPanahi/Llama-3-8B-Instruct-v0.8-GGUF
# 9738번 모델 데이터 수집 중입니다.
# mradermacher/L3-8B-Stheno-v3.1-GGUF
# 9739번 모델 데이터 수집 중입니다.
# alexandrainst/da-hatespeech-detection-small
# 9740번 모델 데이터 수집 중입니다.
# TheBloke/Python-Code-33B-GGUF
# 9741번 모델 데이터 수집 중입니다.
# TheTravellingEngineer/llama2-7b-hf-guanaco
# 9742번 모델 데이터 수집 중입니다.
# AiLab-IMCS-UL/lvbert
# 9743번 모델 데이터 수집 중입니다.
# withU/kogpt2-emotion-chatbot
# 9744번 모델 데이터 수집 중입니다.
# Nitral-AI/Prima-LelantaclesV6.69-7b
# 9745번 모델 데이터 수집 중입니다.
# jplu/tf-xlm-roberta-base
# 9746번 모델 데이터 수집 중입니다.
# Mit1208/UDOP-finetuned-DocLayNet
# 9747번 모델 데이터 수집 중입니다.
# RoversX/llama-2-7b-hf-small-shards-Samantha-V1-SFT
# 9748번 모델 데이터 수집 중입니다.
# Lajonbot/Llama-2-13b-hf-instruct-pl-lora_unload
# 9749번 모델 데이터 수집 중입니다.
# TheBloke/DPOpenHermes-7B-v2-GGUF
# 9750번 모델 데이터 수집 중입니다.
# mradermacher/Silicon-Maid-7B-i1-GGUF
# 9751번 모델 데이터 수집 중입니다.
# scherrmann/GermanFinBert_SC_Sentiment
# 9752번 모델 데이터 수집 중입니다.
# Aeala/Alpaca-elina-65b
# 9753번 모델 데이터 수집 중입니다.
# imjeffhi/pokemon_classifier
# 9754번 모델 데이터 수집 중입니다.
# duyntnet/Azzurro-imatrix-GGUF
# 9755번 모델 데이터 수집 중입니다.
# TaylorAI/FLAN-Llama-7B-2_Llama2-7B-Flash_868_full_model
# 9756번 모델 데이터 수집 중입니다.
# Nitral-Archive/Eris-Daturamix-7b
# 9757번 모델 데이터 수집 중입니다.
# cloudyu/Mixtral_7Bx5_MoE_30B
# 9758번 모델 데이터 수집 중입니다.
# KoboldAI/LLaMA2-13B-Erebus-v3
# 9759번 모델 데이터 수집 중입니다.
# TheBloke/agentlm-13B-GGUF
# 9760번 모델 데이터 수집 중입니다.
# abideen/AlphaMonarch-dora
# 9761번 모델 데이터 수집 중입니다.
# Nitral-AI/Copium-Cola-9B
# 9762번 모델 데이터 수집 중입니다.
# remyxai/SpaceLLaVA
# 9763번 모델 데이터 수집 중입니다.
# qqlabs/llama2_esci_v1
# 9764번 모델 데이터 수집 중입니다.
# jiajunlong/TinyLLaVA-OpenELM-450M-CLIP-0.55B
# 9765번 모델 데이터 수집 중입니다.
# Weyaxi/Einstein-v2-7B
# 9766번 모델 데이터 수집 중입니다.
# sijunhe/nezha-cn-base
# 9767번 모델 데이터 수집 중입니다.
# fnlp/moss-moon-003-base
# 9768번 모델 데이터 수집 중입니다.
# e-palmisano/Phi3-ITA-mini-4K-instruct
# 9769번 모델 데이터 수집 중입니다.
# Q-bert/Mamba-130M
# 9770번 모델 데이터 수집 중입니다.
# ibivibiv/multimaster-7b-v6
# 9771번 모델 데이터 수집 중입니다.
# google/xtr-base-en
# 9772번 모델 데이터 수집 중입니다.
# BEE-spoke-data/TinyLlama-3T-1.1bee
# 9773번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-en-sq
# 9774번 모델 데이터 수집 중입니다.
# YeungNLP/firefly-llama-30b
# 9775번 모델 데이터 수집 중입니다.
# sonoisa/clip-vit-b-32-japanese-v1
# 9776번 모델 데이터 수집 중입니다.
# batterydata/bde-pos-bert-cased-base
# 9777번 모델 데이터 수집 중입니다.
# adamo1139/Mistral-7B-AEZAKMI-v1
# 9778번 모델 데이터 수집 중입니다.
# luqh/ClinicalT5-large
# 9779번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-en-swc
# 9780번 모델 데이터 수집 중입니다.
# uukuguy/speechless-mistral-7b-dare-0.85
# 9781번 모델 데이터 수집 중입니다.
# pinkmanlove/llama-7b-hf
# 9782번 모델 데이터 수집 중입니다.
# TheBloke/Dolphin2.1-OpenOrca-7B-GGUF
# 9783번 모델 데이터 수집 중입니다.
# huashiyiqike/testmodel
# 9784번 모델 데이터 수집 중입니다.
# vihangd/smartyplats-7b-v1
# 9785번 모델 데이터 수집 중입니다.
# habanoz/TinyLlama-1.1B-intermediate-step-715k-1.5T-lr-5-4epochs-oasst1-top1-instruct-V1
# 9786번 모델 데이터 수집 중입니다.
# dallinmackay/Tron-Legacy-diffusion
# 9787번 모델 데이터 수집 중입니다.
# Natooz/Maestro-REMI-bpe20k
# 9788번 모델 데이터 수집 중입니다.
# sauce1337/AppleSauce-L2-13b
# 9789번 모델 데이터 수집 중입니다.
# sensenova/piccolo-large-zh-v2
# 9790번 모델 데이터 수집 중입니다.
# Azazelle/Argetsu
# 9791번 모델 데이터 수집 중입니다.
# bofenghuang/vigogne-13b-chat
# 9792번 모델 데이터 수집 중입니다.
# CofeAI/FLM-101B
# 9793번 모델 데이터 수집 중입니다.
# MohamedRashad/arabic-small-nougat
# 9794번 모델 데이터 수집 중입니다.
# quantumaikr/QuantumLM-7B
# 9795번 모델 데이터 수집 중입니다.
# cognitivecomputations/dolphin-2.9.2-qwen2-72b-gguf
# 9796번 모델 데이터 수집 중입니다.
# lamini/instruct-tuned-3b
# 9797번 모델 데이터 수집 중입니다.
# jjzha/esco-xlm-roberta-large
# 9798번 모델 데이터 수집 중입니다.
# Isaak-Carter/J.O.S.I.E.3-Beta11-7B-slerp
# 9799번 모델 데이터 수집 중입니다.
# TheBloke/TinyLlama-1.1B-intermediate-step-1431k-3T-GGUF
# 9800번 모델 데이터 수집 중입니다.
# Danielbrdz/Barcenas-6b
# 9801번 모델 데이터 수집 중입니다.
# BEE-spoke-data/zephyr-220m-sft-full
# 9802번 모델 데이터 수집 중입니다.
# dima806/face_obstruction_image_detection
# 9803번 모델 데이터 수집 중입니다.
# TheBloke/Noromaid-13B-v0.1.1-GGUF
# 9804번 모델 데이터 수집 중입니다.
# HUBioDataLab/SELFormer
# 9805번 모델 데이터 수집 중입니다.
# QuantFactory/Turkish-Llama-8b-v0.1-GGUF
# 9806번 모델 데이터 수집 중입니다.
# Yntec/AnythingV7
# 9807번 모델 데이터 수집 중입니다.
# Azazelle/Dumb-Maidlet
# 9808번 모델 데이터 수집 중입니다.
# Jayant9928/orpo_med_v3
# 9809번 모델 데이터 수집 중입니다.
# TheBloke/Aurora-Nights-70B-v1.0-GGUF
# 9810번 모델 데이터 수집 중입니다.
# mradermacher/dolphin-2.9.2-Phi-3-Medium-abliterated-GGUF
# 9811번 모델 데이터 수집 중입니다.
# YeungNLP/firefly-llama-13b-v1.2
# 9812번 모델 데이터 수집 중입니다.
# edor/Platypus2-mini-7B
# 9813번 모델 데이터 수집 중입니다.
# google/efficientnet-b1
# 9814번 모델 데이터 수집 중입니다.
# facebook/mask2former-swin-large-cityscapes-panoptic
# 9815번 모델 데이터 수집 중입니다.
# TheBloke/Akins-3B-GGUF
# 9816번 모델 데이터 수집 중입니다.
# TheBloke/Vigogne-2-13B-Instruct-GPTQ
# 9817번 모델 데이터 수집 중입니다.
# leo911kim/Exodia-7B
# 9818번 모델 데이터 수집 중입니다.
# HuggingFaceH4/mistral-7b-sft-alpha
# 9819번 모델 데이터 수집 중입니다.
# amazingvince/zephyr-smol_llama-100m-dpo-full
# 9820번 모델 데이터 수집 중입니다.
# dacorvo/tiny-random-llama
# 9821번 모델 데이터 수집 중입니다.
# mrm8488/spanbert-finetuned-squadv2
# 9822번 모델 데이터 수집 중입니다.
# chargoddard/internlm2-base-20b-llama
# 9823번 모델 데이터 수집 중입니다.
# decruz07/kellemar-DPO-7B-v1.01
# 9824번 모델 데이터 수집 중입니다.
# NewstaR/Porpoise-6b-instruct
# 9825번 모델 데이터 수집 중입니다.
# jondurbin/airoboros-65b-gpt4-1.3
# 9826번 모델 데이터 수집 중입니다.
# xaviviro/OpenHermes-2.5-FLOR-6.3B
# 9827번 모델 데이터 수집 중입니다.
# duyntnet/Dr_Samantha-7b-imatrix-GGUF
# 9828번 모델 데이터 수집 중입니다.
# mradermacher/L3-8B-daybreak-stheno-v3.1-GGUF
# 9829번 모델 데이터 수집 중입니다.
# jinaai/jina-bert-flash-implementation
# 9830번 모델 데이터 수집 중입니다.
# batterydata/batterybert-cased-squad-v1
# 9831번 모델 데이터 수집 중입니다.
# second-state/Dolphin-2.7-mixtral-8x7b-GGUF
# 9832번 모델 데이터 수집 중입니다.
# unaidedelf87777/wizard-mistral-v0.1
# 9833번 모델 데이터 수집 중입니다.
# Ba2han/BruinsV2-OpHermesNeu-11B
# 9834번 모델 데이터 수집 중입니다.
# Steelskull/L3-Aethora-15B
# 9835번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-en-toi
# 9836번 모델 데이터 수집 중입니다.
# TheBloke/una-xaberius-34b-v1beta-GGUF
# 9837번 모델 데이터 수집 중입니다.
# SteelStorage/Umbra-MoE-4x10.7
# 9838번 모델 데이터 수집 중입니다.
# bond005/wav2vec2-large-ru-golos
# 9839번 모델 데이터 수집 중입니다.
# TheBloke/Poro-34B-GPTQ
# 9840번 모델 데이터 수집 중입니다.
# llama-anon/petra-13b-instruct
# 9841번 모델 데이터 수집 중입니다.
# TheBloke/llama-2-7B-Arguments-GGUF
# 9842번 모델 데이터 수집 중입니다.
# slplab/wav2vec2-xls-r-300m_phone-mfa_korean
# 9843번 모델 데이터 수집 중입니다.
# TheBloke/GPlatty-30B-SuperHOT-8K-fp16
# 9844번 모델 데이터 수집 중입니다.
# Aryanne/Basilisk-4B-gguf
# 9845번 모델 데이터 수집 중입니다.
# mwitiderrick/SwahiliInstruct-v0.2
# 9846번 모델 데이터 수집 중입니다.
# jb2k/bert-base-multilingual-cased-language-detection
# 9847번 모델 데이터 수집 중입니다.
# squarelike/polyglot-ko-medical-5.8b
# 9848번 모델 데이터 수집 중입니다.
# keremberke/yolov8s-plane-detection
# 9849번 모델 데이터 수집 중입니다.
# FelixChao/Severus-7B
# 9850번 모델 데이터 수집 중입니다.
# R136a1/BeyondInfinity-v2-4x7B
# 9851번 모델 데이터 수집 중입니다.
# Pclanglais/TintinIA
# 9852번 모델 데이터 수집 중입니다.
# TeeZee/Bielik-SOLAR-LIKE-10.7B-Instruct-v0.1
# 9853번 모델 데이터 수집 중입니다.
# lvkaokao/llama2-7b-hf-instruction-lora
# 9854번 모델 데이터 수집 중입니다.
# lighteternal/Llama3-merge-biomed-8b
# 9855번 모델 데이터 수집 중입니다.
# TheBloke/Echidna-13B-v0.3-GGUF
# 9856번 모델 데이터 수집 중입니다.
# maidalun1020/bce-reranker-base_v1
# 9857번 모델 데이터 수집 중입니다.
# Mihaiii/Pallas-0.5-LASER-0.4
# 9858번 모델 데이터 수집 중입니다.
# Corianas/590m
# 9859번 모델 데이터 수집 중입니다.
# duyntnet/Antler-7B-evolve-imatrix-GGUF
# 9860번 모델 데이터 수집 중입니다.
# TheBloke/openchat_3.5-GPTQ
# 9861번 모델 데이터 수집 중입니다.
# martyn/mixtral-megamerge-dare-8x7b-v2
# 9862번 모델 데이터 수집 중입니다.
# bespin-global/klue-roberta-base-ner
# 9863번 모델 데이터 수집 중입니다.
# SeacomSrl/SeaPhi3-mini
# 9864번 모델 데이터 수집 중입니다.
# robinsyihab/Sidrap-7B-v2
# 9865번 모델 데이터 수집 중입니다.
# lodrick-the-lafted/Winged-Lagomorph-2x13B
# 9866번 모델 데이터 수집 중입니다.
# mradermacher/openbuddy-yi1.5-9b-v21.1-32k-GGUF
# 9867번 모델 데이터 수집 중입니다.
# TheBloke/Noromaid-13B-v0.1-GGUF
# 9868번 모델 데이터 수집 중입니다.
# Corianas/Quokka_2.7b
# 9869번 모델 데이터 수집 중입니다.
# stablediffusionapi/realistic-vision-v13
# 9870번 모델 데이터 수집 중입니다.
# vmajor/Orca2-13B-selfmerge-39B
# 9871번 모델 데이터 수집 중입니다.
# infinitejoy/wav2vec2-large-xls-r-300m-bulgarian
# 9872번 모델 데이터 수집 중입니다.
# kuleshov-group/caduceus-ph_seqlen-1k_d_model-256_n_layer-4_lr-8e-3
# 9873번 모델 데이터 수집 중입니다.
# OpenBuddy/openbuddy-falcon-40b-v16.1-4k
# 9874번 모델 데이터 수집 중입니다.
# Sharathhebbar24/math_gpt2_sft
# 9875번 모델 데이터 수집 중입니다.
# premai-io/prem-1B-chat
# 9876번 모델 데이터 수집 중입니다.
# michaelfeil/bge-small-en-v1.5
# 9877번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-de-pl
# 9878번 모델 데이터 수집 중입니다.
# TheBloke/Mistral-7B-Instruct-v0.2-DARE-GGUF
# 9879번 모델 데이터 수집 중입니다.
# mradermacher/bangla-llama-7b-instruct-v0.1-i1-GGUF
# 9880번 모델 데이터 수집 중입니다.
# vicgalle/SOLAR-13B-Instruct-v1.0
# 9881번 모델 데이터 수집 중입니다.
# llm-book/bert-base-japanese-v3-marc_ja
# 9882번 모델 데이터 수집 중입니다.
# manishiitg/open-aditi-hi-v1
# 9883번 모델 데이터 수집 중입니다.
# FelixChao/Magician-MoE-4x7B
# 9884번 모델 데이터 수집 중입니다.
# p208p2002/zh-wiki-punctuation-restore
# 9885번 모델 데이터 수집 중입니다.
# sentence-transformers/msmarco-roberta-base-v3
# 9886번 모델 데이터 수집 중입니다.
# royallab/PsyOrca2-13b-DARE
# 9887번 모델 데이터 수집 중입니다.
# Kquant03/Eukaryote-8x7B-bf16
# 9888번 모델 데이터 수집 중입니다.
# Intel/Mistral-7B-v0.1-int4-inc
# 9889번 모델 데이터 수집 중입니다.
# Kquant03/FrankenDPO-4x7B-bf16
# 9890번 모델 데이터 수집 중입니다.
# lvkaokao/llama2-7b-hf-chat-lora-v3
# 9891번 모델 데이터 수집 중입니다.
# QuantFactory/Dorna-Llama3-8B-Instruct-GGUF
# 9892번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-sv-fi
# 9893번 모델 데이터 수집 중입니다.
# Lewdiculous/llama-3-Stheno-Mahou-8B-GGUF-IQ-Imatrix
# 9894번 모델 데이터 수집 중입니다.
# InstaDeepAI/nucleotide-transformer-v2-100m-multi-species
# 9895번 모델 데이터 수집 중입니다.
# PocketDoc/Dans-CreepingSenseOfDoom-13b
# 9896번 모델 데이터 수집 중입니다.
# RatanRohith/NeuralPizza-Valor-7B-Merge-slerp
# 9897번 모델 데이터 수집 중입니다.
# mradermacher/Aura_Qwen_7B-i1-GGUF
# 9898번 모델 데이터 수집 중입니다.
# zarakiquemparte/zaraxls-l2-7b
# 9899번 모델 데이터 수집 중입니다.
# T-Systems-onsite/cross-en-de-fr-roberta-sentence-transformer
# 9900번 모델 데이터 수집 중입니다.
# kaist-ai/CoT-T5-3B
# 9901번 모델 데이터 수집 중입니다.
# neovalle/H4rmoniousAnthea
# 9902번 모델 데이터 수집 중입니다.
# yeontaek/WizardCoder-Python-13B-LoRa
# 9903번 모델 데이터 수집 중입니다.
# TheBloke/Chupacabra-7B-v2-GGUF
# 9904번 모델 데이터 수집 중입니다.
# jaycamper/swin-tiny-patch4-window7-224-finetuned-cifar100
# 9905번 모델 데이터 수집 중입니다.
# jeonsworld/CarbonVillain-en-10.7B-v2
# 9906번 모델 데이터 수집 중입니다.
# fnlp/SpeechGPT-7B-cm
# 9907번 모델 데이터 수집 중입니다.
# BEE-spoke-data/Mixtral-GQA-400m-v2
# 9908번 모델 데이터 수집 중입니다.
# OpenAssistant/falcon-40b-sft-top1-560
# 9909번 모델 데이터 수집 중입니다.
# SanjiWatsuki/Lelantos-DPO-7B
# 9910번 모델 데이터 수집 중입니다.
# Praneeth/StarMix-7B-slerp
# 9911번 모델 데이터 수집 중입니다.
# zarakiquemparte/zararp-l2-7b
# 9912번 모델 데이터 수집 중입니다.
# mradermacher/goliath-120b-i1-GGUF
# 9913번 모델 데이터 수집 중입니다.
# mradermacher/Chewy-Lemon-Cookie-11B-i1-GGUF
# 9914번 모델 데이터 수집 중입니다.
# openai/jukebox-5b-lyrics
# 9915번 모델 데이터 수집 중입니다.
# castorini/monot5-3b-msmarco-10k
# 9916번 모델 데이터 수집 중입니다.
# mradermacher/aya-23-8B-GGUF
# 9917번 모델 데이터 수집 중입니다.
# Corianas/256_5epoch
# 9918번 모델 데이터 수집 중입니다.
# flammenai/Mahou-1.2a-llama3-8B
# 9919번 모델 데이터 수집 중입니다.
# NurtureAI/neural-chat-7b-v3-16k-GGUF
# 9920번 모델 데이터 수집 중입니다.
# migtissera/Tess-2.0-Mixtral-8x7B-v0.2
# 9921번 모델 데이터 수집 중입니다.
# openai/jukebox-1b-lyrics
# 9922번 모델 데이터 수집 중입니다.
# h2m/mhm-7b-v1.3-DPO-1
# 9923번 모델 데이터 수집 중입니다.
# TheBloke/Toppy-M-7B-GPTQ
# 9924번 모델 데이터 수집 중입니다.
# unsloth/OpenHermes-2.5-Mistral-7B-bnb-4bit
# 9925번 모델 데이터 수집 중입니다.
# georgesung/llama3_8b_chat_uncensored
# 9926번 모델 데이터 수집 중입니다.
# bartowski/Llama-3-Orca-1.0-8B-GGUF
# 9927번 모델 데이터 수집 중입니다.
# starsy/Llama-3-70B-Instruct-Gradient-1048k-AWQ
# 9928번 모델 데이터 수집 중입니다.
# Vikhrmodels/VikhrT5-3b
# 9929번 모델 데이터 수집 중입니다.
# DunnBC22/wav2vec2-base-Speech_Emotion_Recognition
# 9930번 모델 데이터 수집 중입니다.
# UBC-NLP/AraT5-msa-base
# 9931번 모델 데이터 수집 중입니다.
# bn22/Nous-Hermes-2-SOLAR-10.7B-MISALIGNED
# 9932번 모델 데이터 수집 중입니다.
# jhu-clsp/bernice
# 9933번 모델 데이터 수집 중입니다.
# Lexic0n/Mistral_7B-Open_Hermes-NSFWV1
# 9934번 모델 데이터 수집 중입니다.
# rakeshkiriyath/gpt2Medium_text_to_sql
# 9935번 모델 데이터 수집 중입니다.
# wenge-research/yayi-uie
# 9936번 모델 데이터 수집 중입니다.
# hooking-dev/Monah-8b-Uncensored-gguf
# 9937번 모델 데이터 수집 중입니다.
# kandinsky-community/kandinsky-2-1-inpaint
# 9938번 모델 데이터 수집 중입니다.
# duyntnet/pygmalion-2-7b-imatrix-GGUF
# 9939번 모델 데이터 수집 중입니다.
# superb/hubert-base-superb-er
# 9940번 모델 데이터 수집 중입니다.
# Weyaxi/Einstein-openchat-7B
# 9941번 모델 데이터 수집 중입니다.
# kekmodel/StopCarbon-10.7B-v6
# 9942번 모델 데이터 수집 중입니다.
# ml6team/mbart-large-cc25-cnn-dailymail-nl-finetune
# 9943번 모델 데이터 수집 중입니다.
# sentence-transformers/msmarco-distilroberta-base-v2
# 9944번 모델 데이터 수집 중입니다.
# manueldeprada/FactCC
# 9945번 모델 데이터 수집 중입니다.
# kykim/albert-kor-base
# 9946번 모델 데이터 수집 중입니다.
# Systran/faster-whisper-base.en
# 9947번 모델 데이터 수집 중입니다.
# setu4993/LEALLA-small
# 9948번 모델 데이터 수집 중입니다.
# TheBloke/Yi-34B-GiftedConvo-merged-GGUF
# 9949번 모델 데이터 수집 중입니다.
# drt/srtk-scorer
# 9950번 모델 데이터 수집 중입니다.
# facebook/hubert-xlarge-ll60k
# 9951번 모델 데이터 수집 중입니다.
# KnutJaegersberg/Deita-20b
# 9952번 모델 데이터 수집 중입니다.
# h2m/mhm-8x7B-FrankenMoE-v1.0
# 9953번 모델 데이터 수집 중입니다.
# Q-bert/Bumblebee-7B
# 9954번 모델 데이터 수집 중입니다.
# SiberiaSoft/SiberianFredT5-instructor
# 9955번 모델 데이터 수집 중입니다.
# georgesung/open_llama_7b_qlora_uncensored
# 9956번 모델 데이터 수집 중입니다.
# Sahajtomar/NER_legal_de
# 9957번 모델 데이터 수집 중입니다.
# Aeala/GPT4-x-AlpacaDente-30b
# 9958번 모델 데이터 수집 중입니다.
# cloudyu/Mixtral-8x7B-Instruct-v0.1-DPO
# 9959번 모델 데이터 수집 중입니다.
# abacusai/MM-Orc-Vic-bagel-34b-c1000
# 9960번 모델 데이터 수집 중입니다.
# mradermacher/Nous-Hermes-2-Yi-34B-i1-GGUF
# 9961번 모델 데이터 수집 중입니다.
# Jean-Baptiste/roberta-large-financial-news-sentiment-en
# 9962번 모델 데이터 수집 중입니다.
# jpacifico/French-Alpaca-Phi-3-beta-GGUF
# 9963번 모델 데이터 수집 중입니다.
# TheBloke/X-MythoChronos-13B-GGUF
# 9964번 모델 데이터 수집 중입니다.
# diffnamehard/Psyfighter2-Noromaid-ties-Capybara-13B
# 9965번 모델 데이터 수집 중입니다.
# vinai/vinai-translate-en2vi
# 9966번 모델 데이터 수집 중입니다.
# TheBloke/upstage-llama-30b-instruct-2048-GGUF
# 9967번 모델 데이터 수집 중입니다.
# TheBloke/Inkbot-13B-8k-0.2-GGUF
# 9968번 모델 데이터 수집 중입니다.
# utrobinmv/t5_translate_en_ru_zh_base_200
# 9969번 모델 데이터 수집 중입니다.
# Aeala/GPT4-x-Alpasta-13b
# 9970번 모델 데이터 수집 중입니다.
# dvilasuero/NeuralHermes-2.5-Mistral-7B-distilabel
# 9971번 모델 데이터 수집 중입니다.
# stefan-it/wav2vec2-large-xlsr-53-basque
# 9972번 모델 데이터 수집 중입니다.
# HorcruxNo13/swinv2-tiny-patch4-window8-256
# 9973번 모델 데이터 수집 중입니다.
# Titeiiko/OTIS-Official-Spam-Model
# 9974번 모델 데이터 수집 중입니다.
# mradermacher/miqu-1-103b-i1-GGUF
# 9975번 모델 데이터 수집 중입니다.
# MIT/ast-finetuned-audioset-16-16-0.442
# 9976번 모델 데이터 수집 중입니다.
# MaziyarPanahi/Qwen1.5-8x7b-v0.1-GGUF
# 9977번 모델 데이터 수집 중입니다.
# jilp00/Hermes-2-SOLAR-10.7B-Symbolic
# 9978번 모델 데이터 수집 중입니다.
# bhavinjawade/SOLAR-10B-Nector-DPO-Jawade
# 9979번 모델 데이터 수집 중입니다.
# yjernite/bart_eli5
# 9980번 모델 데이터 수집 중입니다.
# saishf/Llama4Some-SOVL-4x8B-L3-V1
# 9981번 모델 데이터 수집 중입니다.
# hearmeneigh/sd21-e621-rising-v2
# 9982번 모델 데이터 수집 중입니다.
# MathLLMs/MathCoder-L-7B
# 9983번 모델 데이터 수집 중입니다.
# OpenBuddy/openbuddy-deepseek-67b-v15.1
# 9984번 모델 데이터 수집 중입니다.
# s-nlp/ruT5-base-detox
# 9985번 모델 데이터 수집 중입니다.
# BAAI/JudgeLM-7B-v1.0
# 9986번 모델 데이터 수집 중입니다.
# mradermacher/L3-8B-sunfall-Stheno-v3.1-GGUF
# 9987번 모델 데이터 수집 중입니다.
# Helsinki-NLP/opus-mt-fr-ru
# 9988번 모델 데이터 수집 중입니다.
# TheBloke/CAMEL-33B-Combined-Data-SuperHOT-8K-fp16
# 9989번 모델 데이터 수집 중입니다.
# Corianas/Quokka_1.3b
# 9990번 모델 데이터 수집 중입니다.
# yleo/EmertonMonarch-7B
# 9991번 모델 데이터 수집 중입니다.
# kangqi-ni/mistral-7b-instruct-v0.1-class-bio-tutor-dpo
# 9992번 모델 데이터 수집 중입니다.
# microsoft/swin-base-patch4-window12-384
# 9993번 모델 데이터 수집 중입니다.
# SanjiWatsuki/openchat-3.5-1210-starling-slerp
# 9994번 모델 데이터 수집 중입니다.
# KaeriJenti/kaori-34b-v4
# 9995번 모델 데이터 수집 중입니다.
# TheBloke/Lumosia-MoE-4x10.7-GGUF
# 9996번 모델 데이터 수집 중입니다.
# Yntec/fennPhoto
# 9997번 모델 데이터 수집 중입니다.
# TheBloke/orca_mini_v3_13B-GGUF
# 9998번 모델 데이터 수집 중입니다.
# trl-internal-testing/tiny-random-GPT2Model
# 9999번 모델 데이터 수집 중입니다.
# Corianas/Quokka_590m
# 10000번 모델 데이터 수집 중입니다.
# Data collection completed
